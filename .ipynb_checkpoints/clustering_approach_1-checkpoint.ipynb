# %% [markdown]
# Bachelor thesis - Richard Borschke - 7337876 - University of Cologne - A spatio-temporal analysis of usage patterns in free-floating shared mobility
#
#
# # Clustering Trip Types Based On Centrality
#
# This notebook contains the identification of trip types. Following steps are performed:
# * Feature selection
# * Feature scaling via MinMaxScaler
# * Clustering of trip types via k-means
# * Evaluation of clustering (select k)
# * Interpretation and visualization of cluster results
# * Distribution of identified trip types among mobility modes

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import glob

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="white")

from sklearn.preprocessing import MinMaxScaler


from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

import time
# import numpy as np

# %% [markdown]
# ### Load Data

# %%
# load monthly data of mode based on selected months
def load_data(mode, months):
    first_read = True
    
    for month in months:
        data_month = pd.concat([pd.read_csv(file) for file in glob.glob('Data/Modes/data_supplemented_{}_{}.csv'.format(mode, month))], ignore_index = True)
        if (first_read):
            data_full = data_month
            first_read = False
        else:
            data_full = pd.concat([data_full, data_month], ignore_index=True)
    
    return data_full

# load full data of mode
def load_data_mode_full(mode):
    data_mode_full = pd.read_csv('Data/Modes/data_supplemented_full_{}.csv'.format(mode))
    
    return data_mode_full

# %%
# define months for data loading (YYYYMM)
months = ['201911', '201912', '202001', '202002']

#load data by months
load_monthly_data = False

if (load_monthly_data):
    data_car = load_data('car', months)
    data_bicycle = load_data('bicycle', months)
    data_scooter = load_data('scooter', months)
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %%
# read in desired data
# set True if full data set load is desired
load_full_data = True

if (load_full_data):
    data_car = load_data_mode_full('car')
    data_bicycle = load_data_mode_full('bicycle')
    data_scooter = load_data_mode_full('scooter')
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %% [markdown]
# ### Feature selection

# %%
# select only dist features (based on manuelly defined trip types in literature) and id + vehicleType for later interpretation
dfWARNING = data_full[['id','vehicleType','dist_center_start','dist_center_end']]

df = dfWARNING.sample(n=100000, random_state=1)
df.columns
# Out:
# Index(['id', 'vehicleType', 'dist_center_start', 'dist_center_end'], dtype='object')

# %%
# plot features to visually observe structure of data
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=df, marker='+', height=12, aspect=1)

# %%
# remove extreme outliers
df = df[(df['dist_center_start']<11000)&(df['dist_center_end']<11000)]

# plot indicates four interpretable convex clusters
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=df, marker='+', height=12, aspect=1)

# %% [markdown]
# ### Feature scaling

# %%
# look at feature skewness
plt.figure(figsize=(5,4))
sns.boxplot(data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]),
#  [Text(0, 0, 'dist_center_start'), Text(1, 0, 'dist_center_end')])

# %%
df_minmax = df[['dist_center_start','dist_center_end']].copy()

# save names
names = df_minmax.columns

# scale data
scaler = MinMaxScaler()
scaler.fit(df_minmax)
df_minmax = scaler.transform(df_minmax)

# convert scaled array into dataframe
scaled_df = pd.DataFrame(df_minmax, columns=names) 

scaled_df
# Out:
#        dist_center_start  dist_center_end
# 0               0.194241         0.323381
# 1               0.468336         0.158774
# 2               0.428458         0.050025
# 3               0.212349         0.279288
# 4               0.154661         0.288285
# ...                  ...              ...
# 99210           0.268553         0.146911
# 99211           0.301306         0.238557
# 99212           0.237681         0.351557
# 99213           0.108549         0.118636
# 99214           0.137245         0.157489
#
# [99215 rows x 2 columns]

# %%
# visualize scaled features (still right skewed but scaled from 0 to 1 + 0 remains)
plt.figure(figsize=(5,4))
sns.boxplot(data=scaled_df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]),
#  [Text(0, 0, 'dist_center_start'), Text(1, 0, 'dist_center_end')])

# %%
# plot still indicates four interpretable convex clusters
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=scaled_df, marker='+', height=12, aspect=1)

# %% [markdown]
# ### Cluster Tendency

# %%
from pyclustertend import hopkins
hopkins(scaled_df, 1000)
# Out:
# 0.19517371678704326

# %% [markdown]
# ### Clustering trip types via k-means and parameter selection

# %%
# run k-means multiple times to identify "optimal" k

# with-in cluster sum of squares
wcss=[]

# run loop
for i in range (1,10):   
    start = time.time()
    kmeans = KMeans(i)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)
    end = time.time()
    print(i)
    print(end - start)
# Out:
# 1
# 0.21043610572814941
# 2
# 0.7814404964447021
# 3
# 1.7500219345092773
# 4
# 3.00121808052063
# 5
# 4.343875169754028
# 6
# 3.1863138675689697
# 7
# 5.14440393447876
# 8
# 7.092893123626709
# 9
# 6.0977208614349365

# %%
# plot elbow plot to visually pick "optimal" k
sns.set_theme(style="whitegrid")
g = sns.relplot(x=range(1,10), y=wcss, kind="line", height=5, aspect=2)
g.set_axis_labels('Number of clusters k', 'WCSS')

# %%
# silhouette score EXTREMELY high running time
if (False):
    model = KMeans(random_state=0)

    # select range of cluster number and the metric to observe costs
    visualizer = KElbowVisualizer(model, k=(2,10), metric='silhouette', timings=False)

    # fit and visualize
    visualizer.fit(scaled_df)    
    visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
# cluster data for the chosen number of clusters
k = 7
k_means_new = KMeans(k)

kmeans.fit(scaled_df)

clustered_data = df.copy()
clustered_data['cluster'] = k_means_new.fit_predict(scaled_df)

clustered_data
# Out:
#                                                        id vehicleType  \
# 120814   ZnJlZWZsb2F0OjpjYXIyZ286OldEQzE1Njk0MjFKNjEyMjMw         car
# 60088    ZnJlZWZsb2F0OjpjYXIyZ286OldERDE3NzA0NDFKMTEwOTcz         car
# 46984    ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkzMDI4         car
# 146684   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLNDA4MzE1         car
# 198253   ZnJlZWZsb2F0OjpjYXIyZ286OldNV1hSMTEwMDBURTU3ODA0         car
# ...                                                   ...         ...
# 102591   ZnJlZWZsb2F0OjpjYXIyZ286OldEQzE1Njk0MjFKNjExNDU4         car
# 18155    ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkzODg3         car
# 155003   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzI2OTYz         car
# 125402   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzY5MTM0         car
# 382765  YmlrZTo6dGllcjo6M2Q0YTgxOGMtZTM5OS00MGM5LWI0Yj...     scooter
#
#         dist_center_start  dist_center_end  cluster
# 120814               1986             3290        4
# 60088                4756             1625        6
# 46984                4353              525        6
# 146684               2169             2844        4
# 198253               1586             2935        4
# ...                   ...              ...      ...
# 102591               2737             1505        6
# 18155                3068             2432        6
# 155003               2425             3575        4
# 125402               1120             1219        2
# 382765               1410             1612        2
#
# [99215 rows x 5 columns]

# %% [markdown]
# ### Interpretation and visualization of results
#
# * cluster 0-3: inner-inner trips
# * cluster 4: outer-outer trips
# * cluster 5: outer-inner trips
# * cluster 6: inner-outer trips

# %%
# show cluster results for interpretation
clustered_data.groupby(['cluster']).describe()
# Out:
#         dist_center_start                                                     \
#                     count         mean          std     min      25%     50%
# cluster
# 0                 21771.0  3886.601442   679.620092  2489.0  3336.00  3784.0
# 1                  2840.0  6695.044366  1321.054279  4563.0  5717.75  6474.5
# 2                 24727.0  1253.301897   581.704373    23.0   853.00  1232.0
# 3                  4405.0  7007.147787  1111.840038  5148.0  6221.00  6797.0
# 4                 21467.0  1764.111567   696.533414    24.0  1241.50  1853.0
# 5                  4573.0  2542.975946  1184.449330   146.0  1576.00  2607.0
# 6                 19432.0  3466.007513   732.132000  2226.0  2886.75  3356.0
#
#                          dist_center_end                                    \
#             75%      max           count         mean          std     min
# cluster
# 0        4373.0   5976.0         21771.0  3922.877635   687.456022  2552.0
# 1        7448.0  10129.0          2840.0  6588.892254  1324.894073  4462.0
# 2        1697.0   2605.0         24727.0  1265.251951   594.611463    19.0
# 3        7570.0  10122.0          4405.0  2453.481725  1171.260891    99.0
# 4        2338.0   2990.0         21467.0  3427.512275   723.420385  2181.0
# 5        3498.0   4865.0          4573.0  6957.160289  1115.648296  5123.0
# 6        3948.0   5598.0         19432.0  1692.858944   703.808332    41.0
#
#
#              25%     50%      75%      max
# cluster
# 0        3361.50  3841.0  4430.00   5970.0
# 1        5601.75  6428.0  7243.25  10106.0
# 2         846.00  1251.0  1735.00   2677.0
# 3        1471.00  2502.0  3473.00   4657.0
# 4        2856.00  3312.0  3877.50   5569.0
# 5        6162.00  6738.0  7517.00  10134.0
# 6        1160.00  1776.0  2274.00   2930.0

# %%
# plot cluster results
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data
#                             mean          std     min      25%     50%
# vehicleType cluster
# bicycle     0        3644.168651   546.542469  2689.0  3229.50  3575.0
#             1        6422.421053  1069.272355  4757.0  5960.00  6277.0
#             2        1304.003876   608.202691    24.0   869.50  1304.0
#             3        2803.692308  1329.958669    99.0  1802.00  3371.0
#             4        3117.626205   523.029016  2183.0  2702.00  3065.0
#             5        6165.551724   542.760378  5152.0  5876.00  6145.0
#             6        1844.443409   681.142303    78.0  1332.25  1972.5
# car         0        3959.074826   712.944427  2552.0  3371.00  3893.0
#             1        6682.808184  1404.373887  4478.0  5478.75  6591.5
#             2        1440.599612   602.149561   190.0   987.25  1466.0
#             3        2440.539452  1170.519246   201.0  1464.00  2482.0
#             4        3578.913712   743.978288  2185.0  2982.00  3499.0
#             5        6999.275246  1118.571171  5136.0  6202.50  6794.0
#             6        1594.039128   707.873707    41.0  1045.00  1631.0
# scooter     0        3888.590535   638.741238  2612.0  3381.00  3797.0
#             1        6131.705263   677.198393  4462.0  5756.50  6042.0
#             2        1186.548850   573.054480    19.0   778.00  1163.0
#             3        2880.990741  1073.824891   208.0  2204.00  3206.0
#             4        3127.889321   585.945059  2181.0  2692.00  3015.0
#             5        6047.785311   518.693485  5123.0  5752.00  5976.0
#             6        1968.018164   609.159319   112.0  1616.00  2100.0
#
#
#                          75%      max
# vehicleType cluster
# bicycle     0        4007.00   5640.0
#             1        6309.50   8908.0
#             2        1813.25   2632.0
#             3        3781.25   4319.0
#             4        3462.00   5376.0
#             5        6505.00   7296.0
#             6        2408.00   2927.0
# car         0        4529.00   5970.0
#             1        7518.00  10106.0
#             2        1957.00   2645.0
#             3        3456.00   4657.0
#             4        4118.00   5569.0
#             5        7542.50  10134.0
#             6        2187.00   2928.0
# scooter     0        4288.00   5958.0
#             1        6513.00  10035.0
#             2        1624.00   2677.0
#             3        3721.25   4428.0
#             4        3452.00   5322.0
#             5        6330.00   8069.0
#             6        2423.00   2930.0

# %%
def create_distribution_overview(mode):
    
    distribution = clustered_data[clustered_data['vehicleType']==mode]

    distribution = distribution.groupby(['cluster']).count().copy()
    trip_volume = len(clustered_data[clustered_data['vehicleType']==mode])
    distribution['Distribution [%]'] = distribution['id'] / trip_volume *100

    return distribution[['Distribution [%]']]
# Out:
#          Distribution [%]
# cluster
# 0               23.524500
# 1                3.917967
# 2               11.199439
# 3                7.132837
# 4               23.883563
# 5                7.293163
# 6               23.048532

# %%
create_distribution_overview('car')
# Out:
#          Distribution [%]
# cluster
# 0               23.524500
# 1                3.917967
# 2               11.199439
# 3                7.132837
# 4               23.883563
# 5                7.293163
# 6               23.048532

# %%
create_distribution_overview('bicycle')
# Out:
#          Distribution [%]
# cluster
# 0               15.722976
# 1                0.296366
# 2               32.194665
# 3                0.405553
# 4               27.499610
# 5                0.452348
# 6               23.428482

# %%
create_distribution_overview('scooter')
# Out:
#          Distribution [%]
# cluster
# 0               20.278807
# 1                1.442629
# 2               48.463221
# 3                0.328008
# 4               16.409524
# 5                0.537569
# 6               12.540242

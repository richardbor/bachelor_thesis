# %% [markdown]
# Bachelor thesis - 7337876 - University of Cologne - A spatio-temporal analysis of usage patterns in free-floating shared mobility
#
#
# # Clustering Trip Types Based On Centrality And Duration
#
# This notebook contains the identification of trip types. Following steps are performed:
# * Feature selection
# * Feature scaling via MinMaxScaler
# * Clustering of trip types via k-means
# * Evaluation of clustering (select k)
# * Interpretation and visualization of cluster results
# * Distribution of identified trip types among mobility modes

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import glob

import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_theme(style="white")

from sklearn.preprocessing import MinMaxScaler


from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

import time
# import numpy as np

# %% [markdown]
# ### Load Data

# %%
# load monthly data of mode based on selected months
def load_data(mode, months):
    first_read = True
    
    for month in months:
        data_month = pd.concat([pd.read_csv(file) for file in glob.glob('Data/Modes/data_supplemented_{}_{}.csv'.format(mode, month))], ignore_index = True)
        if (first_read):
            data_full = data_month
            first_read = False
        else:
            data_full = pd.concat([data_full, data_month], ignore_index=True)
    
    return data_full

# load full data of mode
def load_data_mode_full(mode):
    data_mode_full = pd.read_csv('Data/Modes/data_supplemented_full_{}.csv'.format(mode))
    
    return data_mode_full

# %%
# define months for data loading (YYYYMM)
months = ['201911', '201912', '202001', '202002']

#load data by months
load_monthly_data = False

if (load_monthly_data):
    data_car = load_data('car', months)
    data_bicycle = load_data('bicycle', months)
    data_scooter = load_data('scooter', months)
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %%
# read in desired data
# set True if full data set load is desired
load_full_data = True

if (load_full_data):
    data_car = load_data_mode_full('car')
    data_bicycle = load_data_mode_full('bicycle')
    data_scooter = load_data_mode_full('scooter')
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %% [markdown]
# ### Feature selection

# %%
# select only dist features (based on manuelly defined trip types in literature) and id + vehicleType for later interpretation

dfa = data_full[['id','vehicleType','dist_center_start','dist_center_end', 'duration']].copy()
df = dfa.sample(n=80000, random_state=1)

#df = data_full[['id','vehicleType','dist_center_start','dist_center_end', 'duration']].copy()

df['duration'] = df['duration'] / 60
df.columns
# Out:
# Index(['id', 'vehicleType', 'dist_center_start', 'dist_center_end',
#        'duration'],
#       dtype='object')

# %%
# plot features to visually observe structure of data
g = sns.relplot(x="duration", y="duration", kind="scatter", data=df, marker='+', height=12, aspect=1)

# %%
df['duration'].max()
# Out:
# 240.0

# %%
from scipy.stats import zscore
import numpy as np

# remove extreme outliers
# data values that have a z-score sigma greater than a threshold of 4, are declared to be outliers.
z_scores = zscore(df[['dist_center_start','dist_center_end','duration']])
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 4).all(axis=1)
df = df[filtered_entries]
df


#df = df[(df['dist_center_start']<11000)&(df['dist_center_end']<11000)]

# plot indicates four interpretable convex clusters
#g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=df, marker='+', height=12, aspect=1)
# Out:
#                                                        id vehicleType  \
# 120814   ZnJlZWZsb2F0OjpjYXIyZ286OldEQzE1Njk0MjFKNjEyMjMw         car
# 60088    ZnJlZWZsb2F0OjpjYXIyZ286OldERDE3NzA0NDFKMTEwOTcz         car
# 46984    ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkzMDI4         car
# 146684   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLNDA4MzE1         car
# 198253   ZnJlZWZsb2F0OjpjYXIyZ286OldNV1hSMTEwMDBURTU3ODA0         car
# ...                                                   ...         ...
# 307119  YmlrZTo6dGllcjo6MzQ5N2U4OTItYjBiOC00YjY2LTg4M2...     scooter
# 273542  YmlrZTo6dGllcjo6ZTgyMGFlZTAtYWQzOS00ZGY1LTk2ZW...     scooter
# 359038  YmlrZTo6dGllcjo6MTlkMjgyOTUtYTBhNC00ZjFlLTk2ND...     scooter
# 65131    ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzc0NDkx         car
# 150449   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzc0NDYx         car
#
#         dist_center_start  dist_center_end   duration
# 120814               1986             3290  20.000000
# 60088                4756             1625  50.016667
# 46984                4353              525  40.000000
# 146684               2169             2844  30.000000
# 198253               1586             2935  25.033333
# ...                   ...              ...        ...
# 307119               2215              941  11.500000
# 273542               2142             2078  10.016667
# 359038                774             1129  10.016667
# 65131                3353             4471  24.983333
# 150449               4930             1870  40.050000
#
# [78382 rows x 5 columns]

# %%
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=df, marker='+', height=12, aspect=1)

# %% [markdown]
# ### Feature scaling

# %%
# look at feature skewness
plt.figure(figsize=(5,4))
sns.boxplot(data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'dist_center_start'),
#   Text(1, 0, 'dist_center_end'),
#   Text(2, 0, 'duration')])

# %%
df_minmax = df[['dist_center_start','dist_center_end', 'duration']].copy()

# save names
names = df_minmax.columns

# scale data
scaler = MinMaxScaler()
scaler.fit(df_minmax)
df_minmax = scaler.transform(df_minmax)

# convert scaled array into dataframe
scaled_df = pd.DataFrame(df_minmax, columns=names) 

scaled_df
# Out:
#        dist_center_start  dist_center_end  duration
# 0               0.194241         0.323381  0.122414
# 1               0.468336         0.158774  0.340269
# 2               0.428458         0.050025  0.267570
# 3               0.212349         0.279288  0.194992
# 4               0.154661         0.288285  0.158945
# ...                  ...              ...       ...
# 78377           0.216901         0.091152  0.060723
# 78378           0.209677         0.203559  0.049958
# 78379           0.074312         0.109738  0.049958
# 78380           0.329507         0.440138  0.158582
# 78381           0.485553         0.182996  0.267933
#
# [78382 rows x 3 columns]

# %%
# visualize scaled features (still right skewed but scaled from 0 to 1 + 0 remains)
plt.figure(figsize=(5,4))
sns.boxplot(data=scaled_df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'dist_center_start'),
#   Text(1, 0, 'dist_center_end'),
#   Text(2, 0, 'duration')])

# %%
# plot still indicates four interpretable convex clusters
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=scaled_df, marker='+', height=12, aspect=1)

# %% [markdown]
# ### Cluster Tendency

# %%
from pyclustertend import hopkins
hopkins(scaled_df, 20000)
# Out:
# 0.13892922119403808

# %% [markdown]
# ### Clustering trip types via k-means and parameter selection

# %%
# run k-means multiple times to identify "optimal" k
from sklearn import metrics
from sklearn.metrics import silhouette_score

# with-in cluster sum of squares
wcss=[]

# silhouette coefficients
silhouette_coefficients = []

# run loop
for i in range (2,15):   
    start = time.time()
    kmeans = KMeans(i)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)
    print(kmeans.inertia_)
    
    score = silhouette_score(scaled_df, kmeans.labels_)
    silhouette_coefficients.append(score)
    print(score)
    
    end = time.time()
    print(i)
    print(end - start)
# Out:
# 1635.1386443765819
# 0.3180690650062172
# 2
# 19.548155546188354
# 1316.9210890450825
# 0.3143829252626987
# 3
# 14.810125589370728
# 1085.2731230930074
# 0.30178549709556657
# 4
# 14.109299421310425
# 916.8166287035573
# 0.2905833743669924
# 5
# 14.948273181915283
# 796.4519614084987
# 0.3048923369174835
# 6
# 16.23075580596924
# 693.8573207414705
# 0.3115543349821684
# 7
# 14.571767807006836
# 631.3543211295084
# 0.3130575007705994
# 8
# 14.252067565917969
# 575.5530764217133
# 0.2969194017323006
# 9
# 14.365162134170532
# 528.275911367906
# 0.2992543461985777
# 10
# 14.357163429260254
# 493.7462588010104
# 0.3004413425096534
# 11
# 15.4182710647583
# 470.3312178756004
# 0.277513789368824
# 12
# 17.15169644355774
# 447.70494925498633
# 0.2702269983113117
# 13
# 17.879475831985474
# 429.7110364910393
# 0.2665052740160397
# 14
# 17.10846519470215

# %%
# plot elbow plot to visually pick "optimal" k
sns.set_theme(style="whitegrid")
g = sns.relplot(x=range(2,15), y=wcss, kind="line", height=5, aspect=1.5)
g.set_axis_labels('Number of clusters k', 'WCSS')

# %%
# plot silhouette coefficients for each k
plt.figure(figsize=(20, 10))
plt.plot(range(2, 15), silhouette_coefficients)
plt.xticks(range(2, 15))
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette coefficient")
plt.show()

# %%
# cluster data for the chosen number of clusters
k = 8
k_means_new = KMeans(k)

kmeans.fit(scaled_df)

clustered_data = df.copy()
clustered_data['cluster'] = k_means_new.fit_predict(scaled_df)

clustered_data
# Out:
#                                                        id vehicleType  \
# 120814   ZnJlZWZsb2F0OjpjYXIyZ286OldEQzE1Njk0MjFKNjEyMjMw         car
# 60088    ZnJlZWZsb2F0OjpjYXIyZ286OldERDE3NzA0NDFKMTEwOTcz         car
# 46984    ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkzMDI4         car
# 146684   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLNDA4MzE1         car
# 198253   ZnJlZWZsb2F0OjpjYXIyZ286OldNV1hSMTEwMDBURTU3ODA0         car
# ...                                                   ...         ...
# 71725    ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjczNjUw         car
# 373590  YmlrZTo6dGllcjo6ZmZiNjJlZDctZjBiMi00OGMxLWE2NT...     scooter
# 330644  YmlrZTo6dGllcjo6ZWQwNDdiMWQtZGQxYy00MTgzLTlhZm...     scooter
# 202888   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzg0NTA5         car
# 138853   ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzY2OTcx         car
#
#         dist_center_start  dist_center_end   duration  cluster
# 120814               1986             3290  20.000000        6
# 60088                4756             1625  50.016667        1
# 46984                4353              525  40.000000        1
# 146684               2169             2844  30.000000        6
# 198253               1586             2935  25.033333        6
# ...                   ...              ...        ...      ...
# 71725                1384             1149  64.716667        4
# 373590               4465             4396   9.966667        7
# 330644               3646              571  25.016667        1
# 202888               1970             3675  50.016667        6
# 138853               4132             2640  60.050000        1
#
# [29399 rows x 6 columns]

# %% [markdown]
# ### Interpretation and visualization of results

# %%
# show cluster results for interpretation
clustered_data.groupby(['cluster']).mean()
# Out:
#          dist_center_start  dist_center_end   duration
# cluster
# 0              1355.777660      1361.197856  14.797375
# 1              3472.255355      1556.108988  31.424790
# 2              6818.390756      2582.012605  40.621148
# 3              2508.404891      6711.657609  38.724072
# 4              2958.372432      2878.732273  92.895593
# 5              6506.833716      6515.133028  28.268196
# 6              1610.420355      3490.733866  28.920621
# 7              3710.696747      3724.828961  19.425314

# %%
# plot cluster results
#g = sns.relplot(x="dist_center_start", y="duration", kind="scatter", data=clustered_data, legend='full', marker='+', hue='cluster', palette='rainbow', height=12, aspect=1)
sns.pairplot(clustered_data, hue="cluster", plot_kws=dict(marker="+", linewidth=1), palette='rainbow', height=12, aspect=1)

# %% [markdown]
# ### Distribution of trip types among mobility modes

# %%
# show cluster distribution
clustered_data.groupby(['vehicleType','cluster']).describe()
# Out:
#                     dist_center_start                                    \
#                                 count         mean          std     min
# vehicleType cluster
# bicycle     0                   689.0  1467.412192   663.322950    30.0
#             1                   318.0  3115.040881   572.068769  1066.0
#             2                     9.0  6077.777778   260.544995  5789.0
#             3                    10.0  2793.800000  1082.637602   784.0
#             4                   107.0  2263.485981  1013.144185   262.0
#             5                     5.0  6069.200000  1841.582662  4745.0
#             6                   344.0  1725.470930   665.588899   116.0
#             7                   447.0  3378.337808   574.961867  2399.0
# car         0                  1476.0  1459.417344   631.026249   140.0
#             1                  3901.0  3532.398359   803.193240  1045.0
#             2                  1391.0  6837.447879  1224.735161  4544.0
#             3                  1407.0  2495.598436  1165.926230   193.0
#             4                  1304.0  3096.913344  1464.180346   190.0
#             5                   731.0  6616.556772  1448.624039  4328.0
#             6                  3905.0  1593.563892   694.547159   193.0
#             7                  3519.0  3845.972151   703.760451  2333.0
# scooter     0                  5391.0  1313.134669   653.376701    23.0
#             1                   543.0  3249.375691   595.191788   922.0
#             2                    28.0  6109.714286   409.753029  5393.0
#             3                    55.0  2784.127273   963.096935   635.0
#             4                    98.0  1873.632653  1181.635573   116.0
#             5                   136.0  5933.161765   681.495689  4440.0
#             6                   880.0  1640.246591   610.948632    79.0
#             7                  2705.0  3589.635860   686.042529  2244.0
#
#                                                        dist_center_end  \
#                          25%     50%      75%      max           count
# vehicleType cluster
# bicycle     0        1019.00  1445.0  1994.00   2883.0           689.0
#             1        2684.75  3108.0  3556.00   4668.0           318.0
#             2        5827.00  6074.0  6367.00   6417.0             9.0
#             3        1898.25  3371.0  3610.75   3704.0            10.0
#             4        1405.50  2360.0  3098.00   4239.0           107.0
#             5        4957.00  5276.0  6146.00   9222.0             5.0
#             6        1224.25  1868.0  2257.75   3124.0           344.0
#             7        2941.00  3305.0  3709.50   5207.0           447.0
# car         0         971.75  1477.0  1963.00   2970.0          1476.0
#             1        2941.00  3490.0  4115.00   5806.0          3901.0
#             2        5998.50  6681.0  7539.00  10076.0          1391.0
#             3        1561.50  2583.0  3435.00   5209.0          1407.0
#             4        1988.75  3103.0  4093.25   9428.0          1304.0
#             5        5306.50  6432.0  7561.00  10113.0           731.0
#             6        1072.00  1608.0  2150.00   3299.0          3905.0
#             7        3292.00  3746.0  4382.50   5874.0          3519.0
# scooter     0         860.00  1244.0  1779.00   2966.0          5391.0
#             1        2911.00  3180.0  3564.50   5325.0           543.0
#             2        5832.00  6043.5  6467.25   6896.0            28.0
#             3        2193.00  2968.0  3498.50   4431.0            55.0
#             4         975.25  1544.0  2564.00   5125.0            98.0
#             5        5445.75  5997.0  6377.75   7846.0           136.0
#             6        1199.50  1744.5  2168.00   2713.0           880.0
#             7        3048.00  3526.0  4090.00   6030.0          2705.0
#
#                                   ...                   duration             \
#                             mean  ...      75%      max    count       mean
# vehicleType cluster               ...
# bicycle     0        1481.509434  ...  2011.00   2955.0    689.0  16.523778
#             1        1615.946541  ...  2101.75   3187.0    318.0  27.293553
#             2        2591.000000  ...  3729.00   4043.0      9.0  28.350000
#             3        6279.400000  ...  6791.25   7296.0     10.0  41.023333
#             4        2315.504673  ...  3094.50   5152.0    107.0  92.623053
#             5        6536.000000  ...  6281.00   8908.0      5.0  10.996667
#             6        3160.962209  ...  3499.25   5376.0    344.0  26.576550
#             7        3387.483221  ...  3704.00   5640.0    447.0  16.365399
# car         0        1447.334688  ...  1943.50   2732.0   1476.0  23.220991
#             1        1541.787747  ...  2112.00   3414.0   3901.0  33.301154
#             2        2578.769950  ...  3589.50   5783.0   1391.0  40.990427
#             3        6743.447761  ...  7361.00  10134.0   1407.0  39.141590
#             4        2982.304448  ...  3879.25   9155.0   1304.0  94.117996
#             5        6592.659371  ...  7424.00  10071.0    731.0  31.532171
#             6        3561.427145  ...  4147.00   5489.0   3905.0  31.393111
#             7        3842.307474  ...  4386.00   5934.0   3519.0  25.998664
# scooter     0        1322.237989  ...  1814.50   2911.0   5391.0  12.270432
#             1        1623.952118  ...  2106.50   3079.0    543.0  20.364088
#             2        2740.214286  ...  3724.50   4208.0     28.0  26.220238
#             3        5977.000000  ...  6184.50   8069.0     55.0  27.625152
#             4        2115.540816  ...  2975.75   6480.0     98.0  76.927721
#             5        6097.661765  ...  6486.75   8064.0    136.0  11.359314
#             6        3305.943182  ...  3600.50   5285.0    880.0  18.865265
#             7        3627.744547  ...  4162.00   5853.0   2705.0  11.379532
#
#                                                                              \
#                            std        min        25%        50%         75%
# vehicleType cluster
# bicycle     0         6.738296   4.716667  10.300000  15.016667   20.000000
#             1        10.482884   4.700000  20.000000  25.000000   30.283333
#             2         6.047141  19.983333  25.000000  29.950000   34.733333
#             3        15.437491  25.283333  29.987500  36.866667   43.833333
#             4        17.726935  60.000000  79.700000  90.016667  109.991667
#             5         2.416908   9.700000   9.733333   9.966667   10.283333
#             6        10.993957   9.666667  19.983333  24.983333   30.000000
#             7         7.439559   4.716667  10.016667  15.000000   19.983333
# car         0         8.827059   4.983333  15.120833  20.275000   29.454167
#             1        11.354621   9.700000  25.000000  30.033333   40.016667
#             2        15.862034   9.983333  30.000000  39.950000   49.983333
#             3        14.786052  10.016667  29.983333  35.016667   45.066667
#             4        24.832294  59.566667  74.700000  89.933333  114.983333
#             5        18.193910   4.683333  19.983333  29.700000   39.983333
#             6        11.004825   5.250000  24.966667  30.000000   39.683333
#             7        10.429571   4.700000  19.950000  25.000000   30.366667
# scooter     0         6.169006   3.833333   9.966667  10.016667   15.000000
#             1         9.888328   5.000000  14.983333  19.650000   24.941667
#             2         9.525384  14.983333  20.012500  25.000000   30.000000
#             3        11.480248  14.416667  20.000000  25.016667   30.033333
#             4        15.901328  59.950000  69.970833  70.016667   75.012500
#             5         7.625758   4.650000   5.233333  10.000000   14.808333
#             6         8.153711   4.716667  14.966667  15.275000   20.316667
#             7         5.091267   4.416667   9.883333  10.000000   14.983333
#
#
#                             max
# vehicleType cluster
# bicycle     0         60.016667
#             1         65.016667
#             2         35.000000
#             3         71.216667
#             4        120.000000
#             5         15.300000
#             6         64.966667
#             7         49.716667
# car         0         60.266667
#             1         70.300000
#             2        119.966667
#             3        120.016667
#             4        145.550000
#             5        140.000000
#             6         65.366667
#             7         60.016667
# scooter     0         65.033333
#             1         65.283333
#             2         60.016667
#             3         64.983333
#             4        120.000000
#             5         70.033333
#             6         65.000000
#             7         55.000000
#
# [24 rows x 24 columns]

# %%
def create_distribution_overview(mode):
    
    distribution = clustered_data[clustered_data['vehicleType']==mode]

    distribution = distribution.groupby(['cluster']).count().copy()
    trip_volume = len(clustered_data[clustered_data['vehicleType']==mode])
    distribution['Distribution [%]'] = distribution['id'] / trip_volume *100

    return distribution[['Distribution [%]']]

# %%
create_distribution_overview('car')
# Out:
#          Distribution [%]
# cluster
# 0                8.370194
# 1               22.122037
# 2                7.888171
# 3                7.978904
# 4                7.394805
# 5                4.145401
# 6               22.144720
# 7               19.955767

# %%
create_distribution_overview('bicycle')
# Out:
#          Distribution [%]
# cluster
# 0               35.717989
# 1               16.485226
# 2                0.466563
# 3                0.518403
# 4                5.546916
# 5                0.259202
# 6               17.833074
# 7               23.172628

# %%
create_distribution_overview('scooter')
# Out:
#          Distribution [%]
# cluster
# 0               54.808865
# 1                5.520537
# 2                0.284669
# 3                0.559170
# 4                0.996340
# 5                1.382676
# 6                8.946726
# 7               27.501017

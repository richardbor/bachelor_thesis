# %% [markdown]
# Bachelor thesis - Richard Borschke - 7337876 - University of Cologne - A spatio-temporal analysis of usage patterns in free-floating shared mobility
#
#
# # Clustering Trip Types Based On Centrality, Duration And Cyclic Time
#
# This notebook contains the identification of trip types. Following steps are performed:
# * Feature selection
# * Feature scaling via MinMaxScaler
# * Clustering of trip types via k-means
# * Evaluation of clustering (select k)
# * Interpretation and visualization of cluster results
# * Distribution of identified trip types among mobility modes

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import glob

import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_theme(style="white")

from sklearn.preprocessing import MinMaxScaler


from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

import time
# import numpy as np

# %% [markdown]
# ### Load Data

# %%
# load monthly data of mode based on selected months
def load_data(mode, months):
    first_read = True
    
    for month in months:
        data_month = pd.concat([pd.read_csv(file) for file in glob.glob('Data/Modes/data_supplemented_{}_{}.csv'.format(mode, month))], ignore_index = True)
        if (first_read):
            data_full = data_month
            first_read = False
        else:
            data_full = pd.concat([data_full, data_month], ignore_index=True)
    
    return data_full

# load full data of mode
def load_data_mode_full(mode):
    data_mode_full = pd.read_csv('Data/Modes/data_supplemented_full_{}.csv'.format(mode))
    
    return data_mode_full

# %%
# define months for data loading (YYYYMM)
months = ['201911', '201912', '202001', '202002']

#load data by months
load_monthly_data = False

if (load_monthly_data):
    data_car = load_data('car', months)
    data_bicycle = load_data('bicycle', months)
    data_scooter = load_data('scooter', months)
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %%
# read in desired data
# set True if full data set load is desired
load_full_data = True

if (load_full_data):
    data_car = load_data_mode_full('car')
    data_bicycle = load_data_mode_full('bicycle')
    data_scooter = load_data_mode_full('scooter')
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %% [markdown]
# ### Feature selection

# %%
# select only dist features (based on manuelly defined trip types in literature) and id + vehicleType for later interpretation
#dfWARNING = data_full[['id','vehicleType','dist_center_start','dist_center_end']]
#df = dfWARNING.sample(n=100000, random_state=1)

df = data_full[['id','vehicleType','dist_center_start','dist_center_end', 'duration', 'hour', 'weekday']].copy()
df['duration'] = df['duration'] / 60
df.columns
data_full.columns
# Out:
# Index(['id', 'provider', 'vehicleType', 'date_start', 'time_start', 'date_end',
#        'time_end', 'year', 'month', 'weekday', 'hour', 'weekend',
#        'longitude_start', 'latitude_start', 'longitude_end', 'latitude_end',
#        'coordinates_start', 'coordinates_end', 'distance', 'duration', 'speed',
#        'time_basket', 'dist_center_start', 'dist_center_end', 'POI_aero_start',
#        'POI_aero_end', 'POI_art_culture_entertainment_start',
#        'POI_art_culture_entertainment_end', 'POI_education_start',
#        'POI_education_end', 'POI_finance_start', 'POI_finance_end',
#        'POI_food_drink_start', 'POI_food_drink_end', 'POI_healthcare_start',
#        'POI_healthcare_end', 'POI_history_start', 'POI_history_end',
#        'POI_leisure_start', 'POI_leisure_end', 'POI_office_start',
#        'POI_office_end', 'POI_sport_start', 'POI_sport_end', 'POI_shop_start',
#        'POI_shop_end', 'POI_tourism_start', 'POI_tourism_end',
#        'POI_transport_start', 'POI_transport_end'],
#       dtype='object')

# %%
# plot features to visually observe structure of data
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=df, marker='+', height=12, aspect=1)

# %%
# remove extreme outliers
df = df[(df['dist_center_start']<11000)&(df['dist_center_end']<11000)]

# plot indicates four interpretable convex clusters
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=df, marker='+', height=12, aspect=1)

# %% [markdown]
# ### Feature scaling

# %%
# look at feature skewness
plt.figure(figsize=(5,4))
sns.boxplot(data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'dist_center_start'),
#   Text(1, 0, 'dist_center_end'),
#   Text(2, 0, 'duration')])

# %%
df_minmax = df[['dist_center_start','dist_center_end', 'duration']].copy()

# save names
names = df_minmax.columns

# scale data
scaler = MinMaxScaler()
scaler.fit(df_minmax)
df_minmax = scaler.transform(df_minmax)

# convert scaled array into dataframe
scaled_df = pd.DataFrame(df_minmax, columns=names) 

scaled_df
# Out:
#         dist_center_start  dist_center_end  duration
# 0                0.497973         0.464763  0.028911
# 1                0.046268         0.090555  0.071258
# 2                0.200791         0.467979  0.071258
# 3                0.289174         0.361439  0.092290
# 4                0.519031         0.261039  0.092290
# ...                   ...              ...       ...
# 401617           0.015917         0.035384  0.029263
# 401618           0.354325         0.407934  0.050506
# 401619           0.196639         0.305098  0.050506
# 401620           0.275136         0.286480  0.008160
# 401621           0.285517         0.352763  0.029403
#
# [401622 rows x 3 columns]

# %%
# visualize scaled features (still right skewed but scaled from 0 to 1 + 0 remains)
plt.figure(figsize=(5,4))
sns.boxplot(data=scaled_df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'dist_center_start'),
#   Text(1, 0, 'dist_center_end'),
#   Text(2, 0, 'duration')])

# %%
# plot still indicates four interpretable convex clusters
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=scaled_df, marker='+', height=12, aspect=1)

# %% [markdown]
# ### Cluster Tendency

# %%
from pyclustertend import hopkins
hopkins(scaled_df, 10000)
# Out:
# 0.17029096631880625

# %% [markdown]
# ### Clustering trip types via k-means and parameter selection

# %%
# run k-means multiple times to identify "optimal" k

# with-in cluster sum of squares
wcss=[]

# run loop
for i in range (1,15):   
    start = time.time()
    kmeans = KMeans(i)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)
    end = time.time()
    print(i)
    print(end - start)
# Out:
# 1
# 1.837937593460083
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-b9e6413b1fb5> in <module>
#       8     start = time.time()
#       9     kmeans = KMeans(i)
# ---> 10     kmeans.fit(scaled_df)
#      11     wcss.append(kmeans.inertia_)
#      12     end = time.time()
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     312     # init
#     313     centers = _init_centroids(X, n_clusters, init, random_state=random_state,
# --> 314                               x_squared_norms=x_squared_norms)
#     315     centers = np.ascontiguousarray(centers)
#     316     if verbose:
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _init_centroids(X, k, init, random_state, x_squared_norms, init_size)
#     624     if isinstance(init, str) and init == 'k-means++':
#     625         centers = _k_init(X, k, random_state=random_state,
# --> 626                           x_squared_norms=x_squared_norms)
#     627     elif isinstance(init, str) and init == 'random':
#     628         seeds = random_state.permutation(n_samples)[:k]
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _k_init(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     119         np.minimum(closest_dist_sq, distance_to_candidates,
#     120                    out=distance_to_candidates)
# --> 121         candidates_pot = distance_to_candidates.sum(axis=1)
#     122
#     123         # Decide which candidate is the best
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
# plot elbow plot to visually pick "optimal" k
sns.set_theme(style="whitegrid")
g = sns.relplot(x=range(1,15), y=wcss, kind="line", height=5, aspect=1.5)
g.set_axis_labels('Number of clusters k', 'WCSS')

# %%
# silhouette score EXTREMELY high running time
if (False):
    model = KMeans(random_state=0)

    # select range of cluster number and the metric to observe costs
    visualizer = KElbowVisualizer(model, k=(2,15), metric='silhouette', timings=False)

    # fit and visualize
    visualizer.fit(scaled_df)    
    visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
# cluster data for the chosen number of clusters
k = 8
k_means_new = KMeans(k)

kmeans.fit(scaled_df)

clustered_data = df.copy()
clustered_data['cluster'] = k_means_new.fit_predict(scaled_df)

clustered_data
# Out:
#                                                        id vehicleType  \
# 0        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzE5MTQy         car
# 1        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzIxNTM2         car
# 2        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzcyNDA3         car
# 3        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkwNTc5         car
# 4        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkzNjQy         car
# ...                                                   ...         ...
# 404858  YmlrZTo6dGllcjo6YTFlMmYzZjEtNjkyZS00NjA4LWE5YT...     scooter
# 404859  YmlrZTo6dGllcjo6OGUxYjAwNDUtMDY3NS00Mzc4LTk3Yz...     scooter
# 404860  YmlrZTo6dGllcjo6ZGE1NmNkMDgtN2Q5ZS00YzE0LWI2OT...     scooter
# 404861  YmlrZTo6dGllcjo6NzRlY2JjZTYtZWQ3Yi00ZGY3LWJmMG...     scooter
# 404862  YmlrZTo6dGllcjo6MTdiZDhhNzgtNzFiMy00NzRkLWJhND...     scooter
#
#         dist_center_start  dist_center_end   duration  cluster
# 0                    5055             4787   9.916667        2
# 1                     486              948  19.950000        1
# 2                    2049             4820  19.950000        6
# 3                    2943             3727  24.933333        2
# 4                    5268             2697  24.933333        2
# ...                   ...              ...        ...      ...
# 404858                179              382  10.000000        1
# 404859               3602             4204  15.033333        2
# 404860               2007             3149  15.033333        6
# 404861               2801             2958   5.000000        6
# 404862               2906             3638  10.033333        2
#
# [401622 rows x 6 columns]

# %% [markdown]
# ### Interpretation and visualization of results
#
# * cluster: inner-inner trips
# * cluster: outer-outer trips
# * cluster: outer-inner trips
# * cluster: inner-outer trips

# %%
# show cluster results for interpretation
clustered_data.groupby(['cluster']).describe()
# Out:
#         dist_center_start                                                     \
#                     count         mean          std     min      25%     50%
# cluster
# 0                 76360.0  3456.474987   733.389152  1739.0  2878.00  3349.0
# 1                 98099.0  1253.502554   586.341325    18.0   850.00  1228.0
# 2                 85524.0  3875.142744   681.833795  2485.0  3322.00  3774.0
# 3                 18049.0  2538.350158  1176.687831   142.0  1586.00  2596.0
# 4                 17429.0  6993.162430  1139.625738  4832.0  6184.00  6774.0
# 5                 12940.0  2974.863756  1499.859132    49.0  1843.75  2923.5
# 6                 82343.0  1735.043380   693.372560    18.0  1210.00  1828.0
# 7                 10878.0  6685.607281  1315.641208  4509.0  5734.00  6470.0
#
#                           dist_center_end               ...                   \
#              75%      max           count         mean  ...     75%      max
# cluster                                                 ...
# 0        3935.00   5688.0         76360.0  1698.087140  ...  2281.0   3097.0
# 1        1697.00   2678.0         98099.0  1268.630333  ...  1740.0   2697.0
# 2        4354.00   6115.0         85524.0  3908.549752  ...  4413.0   6129.0
# 3        3493.00   4945.0         18049.0  6977.038285  ...  7546.0  10134.0
# 4        7598.00  10133.0         17429.0  2486.944059  ...  3488.0   5113.0
# 5        3920.25   9761.0         12940.0  3004.396522  ...  3931.0  10024.0
# 6        2309.00   3031.0         82343.0  3440.161726  ...  3907.0   5713.0
# 7        7422.00  10129.0         10878.0  6652.995220  ...  7401.0  10278.0
#
#         duration                                                            \
#            count        mean        std        min         25%         50%
# cluster
# 0        76360.0   29.241381  15.332463   4.100000   19.966667   25.050000
# 1        98099.0   17.278994  12.501764   3.066667   10.000000   14.983333
# 2        85524.0   24.379276  15.791449   3.166667   10.250000   20.016667
# 3        18049.0   39.170479  19.237885   4.716667   25.283333   35.000000
# 4        17429.0   40.826838  19.738479   4.950000   29.950000   35.016667
# 5        12940.0  137.943452  41.805201  79.650000  104.983333  125.016667
# 6        82343.0   27.696555  14.899227   3.333333   15.300000   25.000000
# 7        10878.0   32.201339  26.859633   4.066667   15.000000   25.000000
#
#
#                 75%         max
# cluster
# 0         35.033333   99.983333
# 1         20.016667  104.983333
# 2         34.700000   91.416667
# 3         45.000000  189.983333
# 4         45.383333  185.016667
# 5        165.000000  240.000000
# 6         35.000000   95.266667
# 7         40.000000  240.000000
#
# [8 rows x 24 columns]

# %%
# plot cluster results
g = sns.relplot(x="dist_center_start", y="dist_center_end", kind="scatter", data=clustered_data, marker='+', hue='cluster', palette='rainbow', height=12, aspect=1)

# %% [markdown]
# ### Distribution of trip types among mobility modes

# %%
# show cluster distribution
clustered_data.groupby(['vehicleType','cluster']).describe()
# Out:
#                     dist_center_start                                    \
#                                 count         mean          std     min
# vehicleType cluster
# bicycle     0                  5737.0  3136.505665   533.249113  1809.0
#             1                  8151.0  1347.319593   598.144777    18.0
#             2                  4163.0  3613.014893   548.116154  2595.0
#             3                   137.0  2762.226277  1053.163833   142.0
#             4                   134.0  6268.992537   672.918160  4891.0
#             5                   844.0  2490.742891  1017.705258    49.0
#             6                  6250.0  1929.262880   653.352341    18.0
#             7                    85.0  6124.694118   903.395882  4579.0
# car         0                 55049.0  3580.809515   757.595779  1739.0
#             1                 22867.0  1372.534438   600.697649    41.0
#             2                 53248.0  3930.466797   709.382473  2486.0
#             3                 17325.0  2534.849177  1181.110390   144.0
#             4                 16979.0  7015.915955  1142.469477  4832.0
#             5                 11933.0  3024.541524  1519.274233   155.0
#             6                 55997.0  1640.643106   701.373702   117.0
#             7                  8939.0  6807.619756  1386.466983  4509.0
# scooter     0                 15574.0  3134.860280   554.904159  1828.0
#             1                 67081.0  1201.526513   572.448859    23.0
#             2                 28113.0  3809.171238   629.572067  2485.0
#             3                   587.0  2589.429302  1063.146873   160.0
#             4                   316.0  6077.677215   471.817112  5240.0
#             5                   163.0  1844.760736  1260.415911    75.0
#             6                 20096.0  1937.683718   623.575835    48.0
#             7                  1854.0  6123.044229   669.500482  4540.0
#
#                                                        dist_center_end  \
#                          25%     50%      75%      max           count
# vehicleType cluster
# bicycle     0        2713.00  3090.0  3470.00   5130.0          5737.0
#             1         921.00  1330.0  1842.00   2640.0          8151.0
#             2        3211.50  3493.0  3958.50   6073.0          4163.0
#             3        1980.00  3090.0  3626.00   4568.0           137.0
#             4        5873.00  6183.5  6372.75   9267.0           134.0
#             5        1652.75  2571.5  3240.50   6078.0           844.0
#             6        1485.25  2014.0  2481.00   2999.0          6250.0
#             7        5821.00  6188.0  6376.00   9222.0            85.0
# car         0        2984.00  3505.0  4135.00   5688.0         55049.0
#             1         931.00  1372.0  1870.00   2678.0         22867.0
#             2        3351.00  3855.0  4487.00   6115.0         53248.0
#             3        1574.00  2588.0  3493.00   4945.0         17325.0
#             4        6207.50  6805.0  7631.00  10133.0         16979.0
#             5        1882.00  2976.0  4003.00   9761.0         11933.0
#             6        1090.00  1687.0  2224.00   3031.0         55997.0
#             7        5728.00  6693.0  7764.50  10129.0          8939.0
# scooter     0        2713.25  3017.0  3450.00   5629.0         15574.0
#             1         805.00  1166.0  1612.00   2667.0         67081.0
#             2        3307.00  3704.0  4215.00   6088.0         28113.0
#             3        1855.00  2704.0  3450.00   4564.0           587.0
#             4        5793.75  5985.5  6309.50   8094.0           316.0
#             5         912.50  1525.0  2630.00   5279.0           163.0
#             6        1519.00  2074.0  2423.00   3010.0         20096.0
#             7        5742.25  6039.0  6471.75   9926.0          1854.0
#
#                                   ...                   duration              \
#                             mean  ...      75%      max    count        mean
# vehicleType cluster               ...
# bicycle     0        1854.960955  ...  2414.00   3024.0   5737.0   25.992650
#             1        1327.477365  ...  1839.00   2641.0   8151.0   19.647896
#             2        3624.328609  ...  3978.50   5829.0   4163.0   18.802450
#             3        6210.649635  ...  6373.00   9483.0    137.0   38.269343
#             4        2813.604478  ...  3671.25   4432.0    134.0   35.825249
#             5        2390.699052  ...  3118.25   5904.0    844.0  102.827291
#             6        3118.510720  ...  3466.00   5376.0   6250.0   24.762176
#             7        6127.023529  ...  6384.00   8908.0     85.0   16.933725
# car         0        1609.510109  ...  2211.00   3097.0  55049.0   33.358455
#             1        1410.915293  ...  1909.00   2697.0  22867.0   28.963018
#             2        3956.413950  ...  4527.00   6129.0  53248.0   31.451515
#             3        7012.522482  ...  7601.00  10134.0  17325.0   39.624903
#             4        2481.496142  ...  3485.00   5113.0  16979.0   41.151852
#             5        3052.083047  ...  4004.00  10024.0  11933.0  140.795416
#             6        3575.979570  ...  4125.00   5713.0  55997.0   32.286246
#             7        6755.422754  ...  7641.50  10106.0   8939.0   36.659542
# scooter     0        1953.390330  ...  2406.00   3031.0  15574.0   15.885607
#             1        1212.976834  ...  1661.00   2679.0  67081.0   13.008225
#             2        3859.979333  ...  4267.00   6074.0  28113.0   11.809780
#             3        6108.608177  ...  6344.00   8069.0    587.0   25.968711
#             4        2641.145570  ...  3570.75   4475.0    316.0   25.484441
#             5        2691.006135  ...  3687.50   5282.0    163.0  110.983640
#             6        3161.744477  ...  3480.00   5535.0  20096.0   15.820111
#             7        6183.258360  ...  6559.75  10278.0   1854.0   11.406230
#
#                                                                                \
#                            std        min         25%         50%         75%
# vehicleType cluster
# bicycle     0        15.387348   4.700000   15.033333   20.283333   30.000000
#             1        12.738348   4.000000   14.716667   15.033333   20.216667
#             2        11.984242   4.650000   10.050000   15.016667   20.266667
#             3        17.494533  15.000000   25.033333   34.966667   45.000000
#             4        16.447551  14.966667   25.016667   30.483333   40.000000
#             5        10.660489  79.983333   94.983333  102.633333  110.091667
#             6        14.548869   4.700000   15.016667   20.016667   29.983333
#             7        11.058573   4.983333   10.016667   15.000000   20.000000
# car         0        14.372231   4.483333   24.966667   30.000000   40.000000
#             1        14.838207   4.433333   19.983333   25.000000   35.000000
#             2        15.129668   3.900000   20.016667   29.983333   39.983333
#             3        19.307154   4.716667   29.366667   35.000000   45.016667
#             4        19.785660   4.950000   29.966667   35.033333   48.833333
#             5        42.192363  79.650000  105.016667  130.016667  169.983333
#             6        13.999122   3.900000   24.683333   30.000000   39.966667
#             7        27.369179   4.566667   20.000000   30.000000   44.983333
# scooter     0         9.650143   4.100000   10.000000   14.983333   19.983333
#             1         8.266786   3.066667    9.966667   10.033333   15.016667
#             2         6.816227   3.166667    9.900000   10.016667   14.983333
#             3        11.243210   9.916667   19.983333   24.983333   30.000000
#             4         9.454085   9.783333   19.966667   24.966667   30.000000
#             5        11.044595  79.916667  100.375000  115.650000  120.000000
#             6         9.760357   3.333333   10.000000   14.983333   19.983333
#             7         8.766488   4.066667    8.991667   10.000000   10.612500
#
#
#                             max
# vehicleType cluster
# bicycle     0         95.000000
#             1        100.300000
#             2         85.800000
#             3        105.033333
#             4        110.266667
#             5        120.000000
#             6         95.016667
#             7         85.000000
# car         0         99.983333
#             1        104.983333
#             2         91.416667
#             3        189.983333
#             4        185.016667
#             5        240.000000
#             6         95.266667
#             7        240.000000
# scooter     0         90.016667
#             1         99.966667
#             2         74.983333
#             3         95.000000
#             4         74.966667
#             5        120.000000
#             6         94.983333
#             7        120.000000
#
# [24 rows x 24 columns]

# %%
def create_distribution_overview(mode):
    
    distribution = clustered_data[clustered_data['vehicleType']==mode]

    distribution = distribution.groupby(['cluster']).count().copy()
    trip_volume = len(clustered_data[clustered_data['vehicleType']==mode])
    distribution['Distribution [%]'] = distribution['id'] / trip_volume *100

    return distribution[['Distribution [%]']]

# %%
create_distribution_overview('car')
# Out:
#          Distribution [%]
# cluster
# 0               22.715887
# 1                9.436033
# 2               21.972707
# 3                7.149135
# 4                7.006359
# 5                4.924135
# 6               23.107078
# 7                3.688665

# %%
create_distribution_overview('bicycle')
# Out:
#          Distribution [%]
# cluster
# 0               22.497157
# 1               31.963452
# 2               16.324850
# 3                0.537234
# 4                0.525470
# 5                3.309674
# 6               24.508843
# 7                0.333320

# %%
create_distribution_overview('scooter')
# Out:
#          Distribution [%]
# cluster
# 0               11.641153
# 1               50.141272
# 2               21.013724
# 3                0.438767
# 4                0.236202
# 5                0.121838
# 6               15.021228
# 7                1.385816

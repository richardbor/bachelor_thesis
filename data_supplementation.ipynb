# %% [markdown]
# Bachelor thesis - 7337876 - University of Cologne - A spatio-temporal analysis of usage patterns in free-floating shared mobility
#
#
# # Data Supplementation
#
# This notebook contains the supplementation of data, needed for analysis. Following steps are performed:
# * Data loading of prepared trip files
# * Assignment of time basket of trip (NOT needed)
# * Calculating distance to city center
# * POI type supplementation
# * Save supplemented data and POI data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import glob
from haversine import haversine 

import numpy as np
from sklearn.neighbors import BallTree

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import osmnx as ox
ox.config(log_console=True, use_cache=True)
ox.__version__
# Out:
# '0.16.2'

# %% [markdown]
# ### Load Data

# %%
# load monthly data of mode based on selected months
def load_data(mode, months):
    first_read = True
    
    for month in months:
        data_month = pd.concat([pd.read_csv(file) for file in glob.glob('Data/Modes/data_prepared_{}_{}.csv'.format(mode, month))], ignore_index = True)
        if (first_read):
            data_full = data_month
            first_read = False
        else:
            data_full = pd.concat([data_full, data_month], ignore_index=True)
    
    return data_full

# load full data of mode
def load_data_mode_full(mode):
    data_mode_full = pd.read_csv('Data/Modes/data_prepared_full_{}.csv'.format(mode))
    
    return data_mode_full

# %%
# define months for data loading (YYYYMM)
months = ['201911', '201912', '202001', '202002']

#load data by months
load_monthly_data = False

if (load_monthly_data):
    data_car = load_data('car', months)
    data_bicycle = load_data('bicycle', months)
    data_scooter = load_data('scooter', months)
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %%
# read in desired data
# set True if full data set load is desired
load_full_data = True

if (load_full_data):
    data_car = load_data_mode_full('car')
    data_bicycle = load_data_mode_full('bicycle')
    data_scooter = load_data_mode_full('scooter')
    data_full = pd.concat([data_car, data_bicycle, data_scooter], ignore_index=True)

# %% [markdown]
# ### Time Basket Assignment
#
# Time baskets / Day of Week / Time of Day
# * Morning peak time / Mon - Fri / 5:00 - 8:59
# * Weekday daytime / Mon - Fri / 9:00 - 15:59
# * Evening peak time / Mon - Fri / 16:00 - 18:59
# * Weekday evening / Mon - Fri / 19:00 - 22:59
# * Weekday nighttime / Mon - Fri / 23:00 - 04:59
#
#
# * Weekend daytime / Sat & Sun / 6:00 - 17:59
# * Weekend evening / Sat & Sun / 18:00 - 22:59
# * Weekend nighttime / Sat & Sun / 23:00 - 05:59

# %%
def create_time_baskets(df):
    # create time basket column
    df['time_basket'] = 0
    # assign time baskets
    # for weekday time baskets
    df['time_basket'] = np.where(((df['weekend'] == 0) & (df['hour']>=5) & (df['hour']<9)),'morning_peak_time', df['time_basket'])
    df['time_basket'] = np.where(((df['weekend'] == 0) & (df['hour']>=9) & (df['hour']<16)),'weekday_daytime', df['time_basket'])
    df['time_basket'] = np.where(((df['weekend'] == 0) & (df['hour']>=16) & (df['hour']<19)),'evening_peak_time', df['time_basket'])
    df['time_basket'] = np.where(((df['weekend'] == 0) & (df['hour']>=19) & (df['hour']<23)),'weekday_evening', df['time_basket'])
    df['time_basket'] = np.where(((df['weekend'] == 0) & ((df['hour']>=23) | (df['hour']<5))),'weekday_nighttime', df['time_basket'])

    # for weekend time baskets
    df['time_basket'] = np.where(((df['weekend'] == 1) & (df['hour']>=6) & (df['hour']<18)),'weekend_daytime', df['time_basket'])
    df['time_basket'] = np.where(((df['weekend'] == 1) & (df['hour']>=18) & (df['hour']<23)),'weekend_evening', df['time_basket'])
    df['time_basket'] = np.where(((df['weekend'] == 1) & ((df['hour']>=23) | (df['hour']<6))),'weekend_nighttime', df['time_basket'])
    
    return df

# %%
data_full = create_time_baskets(data_full)
data_full['time_basket'].unique()
# Out:
# array(['weekday_daytime', 'evening_peak_time', 'weekday_evening',
#        'weekday_nighttime', 'morning_peak_time', 'weekend_nighttime',
#        'weekend_daytime', 'weekend_evening'], dtype=object)

# %% [markdown]
# ### Calculating Distance to City Center
#
# * Distance to city center from trip start
# * Distance to city center from trip end

# %%
# calculate haversine distance to city center in m
def calculate_distance_to_city_center(data_full):    
    data_full_d = data_full.copy()
    data_full_d['dist_center_start'] = data_full_d.apply(lambda r: int(haversine((r['latitude_start'], r['longitude_start']), (50.941724380890186, 6.958446824087053))*1000), axis=1) #convert Km to meter
    data_full_d['dist_center_end'] = data_full_d.apply(lambda r: int(haversine((r['latitude_end'], r['longitude_end']), (50.941724380890186, 6.958446824087053))*1000), axis=1) #convert Km to meter
    
    return data_full_d

# %%
# calculate distance to city center (Dom) for both origin and destination
data_full = calculate_distance_to_city_center(data_full)

# %% [markdown]
# ### POI Type Supplementation
#
# * Aeroway
# * Arts, culture and entertainment
# * Education
# * Finance
# * Food and drink
# * Healthcare
# * History
# * Leisure
# * Office
# * Sport
# * Shop
# * Tourism
# * Transporation

# %%
# prepare POI data for assignment to trip data
def prepare_POI_data(POI_data):
    # get names of indexes for which column element_type does not equal node
    indexNames = POI_data[ POI_data['element_type'] != 'node' ].index
    
    # delete these row indexes from dataFrame
    POI_data.drop(indexNames , inplace=True)
    
    # drop all columns except certain ones
    POI_data.drop(POI_data.columns.difference(['unique_id','osmid','geometry','name','amenity']), 1, inplace=True)
    
    # create longitude and latitude columns
    POI_data['longitude'] = POI_data.geometry.x
    POI_data['latitude'] = POI_data.geometry.y     
    
    # create usage count column (check how often and if POI is used as neighbor of trip origin or destination)
    POI_data['usage_count'] = 0
    
    return POI_data

# supplement data with POI types
def supplement_trip_data_with_POI_data(data_trips, trips_start_radians, trips_end_radians, POI_data, POI_name):    
    # extract lat/long pairs as numpy array for POI data
    POI_gps = POI_data[["latitude", "longitude"]].values

    # create the ball tree with haversine metric
    POI_radians = np.radians(POI_gps)
    tree = BallTree(POI_radians, metric='haversine')

    # all POIs within a radius of 300 meters
    distance_in_meters = 300
    
    # approx. mean radius
    earth_radius_in_meters = 6371000
    radius = distance_in_meters / earth_radius_in_meters

    # apply query_radius()
    # distances are the great circle distance on the unit sphere
    is_within_start, distances_start = tree.query_radius(trips_start_radians, r=radius, count_only=False, return_distance=True) 
    is_within_end, distances_end = tree.query_radius(trips_end_radians, r=radius, count_only=False, return_distance=True) 

    # convert distances back to meters
    distances_in_meters_start = distances_start * earth_radius_in_meters
    distances_in_meters_end = distances_end * earth_radius_in_meters
    
    # transform to count value with list comprehension
    distances_in_meters_start[:] = [len(array) for array in distances_in_meters_start]
    distances_in_meters_end[:] = [len(array) for array in distances_in_meters_end]

    #create count column for POI for trip data start and end
    data_trips['{}_start'.format(POI_name)] = distances_in_meters_start
    data_trips['{}_end'.format(POI_name)] = distances_in_meters_end

    # calculate usage count for POI data
    is_within = np.concatenate((is_within_start, is_within_end), axis=0)
    for array in is_within:
        for element in array:
            POI_data.loc[element, 'usage_count'] = POI_data.loc[element, 'usage_count'] + 1
    
    # add identifier column
    POI_data['POI_type'] = POI_name
    
    return data_trips, POI_data

# %%
# extract lat/long pairs as numpy array for trip data start and end
trips_start_gps = data_full[["latitude_start", "longitude_start"]].values
trips_end_gps = data_full[["latitude_end", "longitude_end"]].values

# transform lat/long pairs to radians
trips_start_radians = np.radians(trips_start_gps)
trips_end_radians = np.radians(trips_end_gps)

# %%
# define place for data mining
place = 'Köln, Germany'

# %%
import time

start = time.time()

# aeroway POI for transportation but different radius for assignment (handeled seperately)
tags={'aeroway': 'terminal'}
# retrieving openstreetmap data and preparing data
POI_aero = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_aero = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_aero, 'POI_aero')  

end = time.time()
print(end - start)

POI_aero
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
# 4.867861270904541
#        unique_id     osmid                          name  \
# 0  node/27296045  27296045  Terminal 2 Fluggastbereich D
#
#                    geometry  longitude   latitude  usage_count  POI_type
# 0  POINT (7.11970 50.88054)   7.119703  50.880543         3035  POI_aero

# %%
# arts, culture and entertainment POI
tags = {'amenity': ['arts_centre','cinema', 'brothel', 'casino', 'community_centre', 'gambling', 'love_hotel', 'nightclub', 'planetarium', 'public_bookcase', 'social_centre', 'stripclub', 'studio', 'swingerclub', 'theatre']}
POI_art_culture_entertainment = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_art_culture_entertainment = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_art_culture_entertainment, 'POI_art_culture_entertainment')  
POI_art_culture_entertainment
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid           amenity  \
# 0      node/54020150    54020150           theatre
# 1     node/247382429   247382429       planetarium
# 2     node/256221801   256221801            cinema
# 3     node/257905592   257905592           theatre
# 4     node/258183467   258183467  community_centre
# ..               ...         ...               ...
# 200  node/7704871144  7704871144   public_bookcase
# 201  node/7812771513  7812771513          gambling
# 202  node/7861149238  7861149238            studio
# 203  node/8097066616  8097066616  community_centre
# 204  node/8097951111  8097951111          gambling
#
#                                   name                  geometry  longitude  \
# 0                      Atelier Theater  POINT (6.93548 50.93259)   6.935482
# 1      Planetarium und Sternwarte Köln  POINT (6.95649 50.96660)   6.956487
# 2                           Metropolis  POINT (6.95821 50.95108)   6.958213
# 3                       Gloria Theater  POINT (6.94495 50.93749)   6.944948
# 4          Don-Bosco-Club Köln-Mülheim  POINT (7.01081 50.97438)   7.010811
# ..                                 ...                       ...        ...
# 200                                NaN  POINT (6.90917 50.94801)   6.909171
# 201                    Lido Spielhalle  POINT (7.06945 50.97841)   7.069447
# 202  Filmproduktion Peter Schüttemeyer  POINT (6.93241 50.94004)   6.932407
# 203  Bürgerzentrum Nippes - Turmstraße  POINT (6.95050 50.96453)   6.950498
# 204                                NaN  POINT (6.95326 50.96604)   6.953259
#
#       latitude  usage_count                       POI_type
# 0    50.932594        11058  POI_art_culture_entertainment
# 1    50.966600         4909  POI_art_culture_entertainment
# 2    50.951083         9091  POI_art_culture_entertainment
# 3    50.937488        15074  POI_art_culture_entertainment
# 4    50.974384         1784  POI_art_culture_entertainment
# ..         ...          ...                            ...
# 200  50.948012         4798  POI_art_culture_entertainment
# 201  50.978415            0  POI_art_culture_entertainment
# 202  50.940044         7769  POI_art_culture_entertainment
# 203  50.964528         5972  POI_art_culture_entertainment
# 204  50.966036         5303  POI_art_culture_entertainment
#
# [205 rows x 9 columns]

# %%
# education POI
tags = {'amenity': ['college','driving_school', 'kindergarten', 'language_school', 'library', 'music_school', 'school', 'university']}
POI_education = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_education = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_education, 'POI_education')  
POI_education
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid                  geometry       amenity  \
# 0      node/75874741    75874741  POINT (6.92635 50.95670)        school
# 1     node/160695366   160695366  POINT (6.95199 50.94475)       library
# 2     node/215423659   215423659  POINT (6.90924 50.96505)        school
# 3     node/221175135   221175135  POINT (6.89374 50.97834)        school
# 4     node/223292416   223292416  POINT (6.92708 50.97106)  kindergarten
# ..               ...         ...                       ...           ...
# 303  node/8126692679  8126692679  POINT (6.87622 50.94512)        school
# 304  node/8156001437  8156001437  POINT (6.94488 50.93418)  music_school
# 305  node/8188016679  8188016679  POINT (6.88193 50.95509)  kindergarten
# 306  node/8190632569  8190632569  POINT (6.94920 50.93439)       library
# 307  node/8219769707  8219769707  POINT (6.88119 50.95498)       library
#
#                                             name  longitude   latitude  \
# 0                     Lauder-Morijah-Grundschule   6.926346  50.956699
# 1    Erzbischöfliche Diözesan- und Dombibliothek   6.951991  50.944755
# 2               Montessori-Grundschule Ossendorf   6.909241  50.965055
# 3                 Bildungszentrum Butzweiler Hof   6.893744  50.978343
# 4                                            NaN   6.927081  50.971057
# ..                                           ...        ...        ...
# 303                      Anna-Freud-Förderschule   6.876224  50.945117
# 304                              drummer's focus   6.944881  50.934182
# 305             Kindergruppe Sonnenstrahlen e.V.   6.881928  50.955092
# 306                         Stadtbibliothek Köln   6.949196  50.934391
# 307             Katholische öffentliche Bücherei   6.881189  50.954977
#
#      usage_count       POI_type
# 0           2956  POI_education
# 1           6210  POI_education
# 2           1690  POI_education
# 3            419  POI_education
# 4           1281  POI_education
# ..           ...            ...
# 303          504  POI_education
# 304        10570  POI_education
# 305          226  POI_education
# 306        11800  POI_education
# 307          230  POI_education
#
# [308 rows x 9 columns]

# %%
# finance POI
tags = {'amenity': ['atm','bank', 'bureau_de_change']}
POI_finance = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_finance = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_finance, 'POI_finance')  
POI_finance
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid amenity                   name  \
# 0      node/54749669    54749669    bank     Sparkasse KölnBonn
# 1     node/196170706   196170706    bank              Sparkasse
# 2     node/224445220   224445220    bank              Sparkasse
# 3     node/230226555   230226555    bank              Sparkasse
# 4     node/232284761   232284761     atm     Sparkasse KölnBonn
# ..               ...         ...     ...                    ...
# 358  node/8131880605  8131880605     atm                    NaN
# 359  node/8132374205  8132374205     atm                    NaN
# 360  node/8132374206  8132374206     atm                    NaN
# 361  node/8132435066  8132435066     atm                    NaN
# 362  node/8240060668  8240060668    bank  SB-Station Weidepesch
#
#                      geometry  longitude   latitude  usage_count     POI_type
# 0    POINT (6.94095 50.93541)   6.940948  50.935411        17593  POI_finance
# 1    POINT (6.91989 50.95370)   6.919886  50.953704         5862  POI_finance
# 2    POINT (6.90095 50.95752)   6.900947  50.957519         3482  POI_finance
# 3    POINT (6.89975 50.96789)   6.899752  50.967888         1022  POI_finance
# 4    POINT (6.95012 50.96001)   6.950118  50.960011         4329  POI_finance
# ..                        ...        ...        ...          ...          ...
# 358  POINT (7.00520 50.96093)   7.005200  50.960926         2244  POI_finance
# 359  POINT (6.93897 50.93838)   6.938973  50.938383        19911  POI_finance
# 360  POINT (6.93907 50.93876)   6.939065  50.938760        19862  POI_finance
# 361  POINT (6.94059 50.93533)   6.940585  50.935334        17957  POI_finance
# 362  POINT (6.94838 50.98040)   6.948376  50.980402         1379  POI_finance
#
# [363 rows x 9 columns]

# %%
# food and drink POI
tags = {'amenity': ['bar','biergarten','cafe','drinking_water','fast_food','food_court','ice_cream','pub','restaurant', 'internet_cafe']}
POI_food_drink = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_food_drink = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_food_drink, 'POI_food_drink')  
POI_food_drink
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#             unique_id       osmid     amenity  \
# 0         node/359460      359460   fast_food
# 1         node/359832      359832  restaurant
# 2       node/39606803    39606803   fast_food
# 3       node/54020544    54020544  biergarten
# 4       node/55441368    55441368  restaurant
# ...               ...         ...         ...
# 2840  node/8143715869  8143715869  restaurant
# 2841  node/8182655788  8182655788  restaurant
# 2842  node/8235340508  8235340508  restaurant
# 2843  node/8254554285  8254554285         pub
# 2844  node/8254782402  8254782402  restaurant
#
#                                        name                  geometry  \
# 0                                Papa-Pizza  POINT (6.94125 50.91559)
# 1                                    Campus  POINT (6.96375 50.90516)
# 2                               Burger King  POINT (6.91508 50.94915)
# 3     Biergarten Rathenauplatz Veedelstreff  POINT (6.93697 50.93134)
# 4                              Blauer König  POINT (7.00649 50.94040)
# ...                                     ...                       ...
# 2840                          Jonny Turista  POINT (6.94539 50.93330)
# 2841                             alla Pappa  POINT (6.95854 50.92428)
# 2842                  DOWN TO EARTH NOODLES  POINT (6.92774 50.92020)
# 2843                            Kupferkanne  POINT (6.96652 50.97757)
# 2844                            Wooza Bowls  POINT (6.94560 50.93829)
#
#       longitude   latitude  usage_count        POI_type
# 0      6.941247  50.915591         4393  POI_food_drink
# 1      6.963755  50.905156         3065  POI_food_drink
# 2      6.915085  50.949151         7630  POI_food_drink
# 3      6.936973  50.931336        13363  POI_food_drink
# 4      7.006490  50.940398         2721  POI_food_drink
# ...         ...        ...          ...             ...
# 2840   6.945393  50.933296         7910  POI_food_drink
# 2841   6.958543  50.924280         7978  POI_food_drink
# 2842   6.927742  50.920196         5574  POI_food_drink
# 2843   6.966516  50.977573          903  POI_food_drink
# 2844   6.945600  50.938293        12966  POI_food_drink
#
# [2845 rows x 9 columns]

# %%
# healthcare POI
tags = {'amenity': ['clinic','dentist', 'doctors', 'hospital', 'nursing_home', 'pharmacy', 'social_facility', 'veterinary'],
       'emergency': ['emergency_ward_entrance']}
POI_healthcare = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_healthcare = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_healthcare, 'POI_healthcare')  
POI_healthcare
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid   amenity                         name  \
# 0     node/242516129   242516129  pharmacy             Severin-Apotheke
# 1     node/245988507   245988507   doctors                 Andreas Koch
# 2     node/246271893   246271893  pharmacy  Apotheke am Bilderstöckchen
# 3     node/249759181   249759181  pharmacy              Linden Apotheke
# 4     node/259198454   259198454  pharmacy           Gürzenich-Apotheke
# ..               ...         ...       ...                          ...
# 698  node/8241405142  8241405142       NaN                          NaN
# 699  node/8241405144  8241405144       NaN                          NaN
# 700  node/8241405145  8241405145       NaN                          NaN
# 701  node/8241405146  8241405146       NaN                          NaN
# 702  node/8255125293  8255125293       NaN                          NaN
#
#                      geometry  longitude   latitude  usage_count  \
# 0    POINT (6.95884 50.92396)   6.958838  50.923955         8551
# 1    POINT (6.92525 50.95527)   6.925252  50.955274         3534
# 2    POINT (6.92849 50.97136)   6.928493  50.971362         1286
# 3    POINT (6.85879 51.06506)   6.858786  51.065064            0
# 4    POINT (6.95712 50.93615)   6.957118  50.936152        15388
# ..                        ...        ...        ...          ...
# 698  POINT (6.92405 50.93183)   6.924046  50.931834         5368
# 699  POINT (6.92419 50.93169)   6.924193  50.931687         5368
# 700  POINT (6.92413 50.93184)   6.924130  50.931844         5305
# 701  POINT (6.92418 50.93174)   6.924180  50.931738         5365
# 702  POINT (7.05229 50.93898)   7.052291  50.938977            1
#
#            POI_type
# 0    POI_healthcare
# 1    POI_healthcare
# 2    POI_healthcare
# 3    POI_healthcare
# 4    POI_healthcare
# ..              ...
# 698  POI_healthcare
# 699  POI_healthcare
# 700  POI_healthcare
# 701  POI_healthcare
# 702  POI_healthcare
#
# [703 rows x 9 columns]

# %%
# history POI
tags = {'historic': True}
POI_history = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_history = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_history, 'POI_history')  
POI_history
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#             unique_id       osmid                  geometry  \
# 0       node/28121883    28121883  POINT (6.95713 50.94129)
# 1      node/177488956   177488956  POINT (6.97035 50.93787)
# 2      node/267352592   267352592  POINT (6.95923 50.94143)
# 3      node/292400378   292400378  POINT (6.96873 50.93823)
# 4      node/298083386   298083386  POINT (6.96928 50.92064)
# ...               ...         ...                       ...
# 2052  node/8141400510  8141400510  POINT (6.91091 50.93676)
# 2053  node/8141400511  8141400511  POINT (6.91091 50.93676)
# 2054  node/8141400512  8141400512  POINT (6.91091 50.93676)
# 2055  node/8158308957  8158308957  POINT (6.98733 50.95379)
# 2056  node/8227863109  8227863109  POINT (6.90768 50.95018)
#
#                      name amenity  longitude   latitude  usage_count  \
# 0                     NaN     NaN   6.957128  50.941291        17269
# 1        Römisches Osttor     NaN   6.970346  50.937874         4470
# 2     St. Maria ad Gradus     NaN   6.959232  50.941433        18761
# 3       Kürassier Denkmal     NaN   6.968729  50.938228         2507
# 4           Hafenkran 31a     NaN   6.969281  50.920639         2204
# ...                   ...     ...        ...        ...          ...
# 2052   Alexander Weinberg     NaN   6.910912  50.936760         4006
# 2053     Johanna Weinberg     NaN   6.910911  50.936762         4003
# 2054          Ernst Jacob     NaN   6.910909  50.936764         4002
# 2055               Miriam     NaN   6.987335  50.953793          365
# 2056                  NaN     NaN   6.907678  50.950178         3786
#
#          POI_type
# 0     POI_history
# 1     POI_history
# 2     POI_history
# 3     POI_history
# 4     POI_history
# ...           ...
# 2052  POI_history
# 2053  POI_history
# 2054  POI_history
# 2055  POI_history
# 2056  POI_history
#
# [2057 rows x 9 columns]

# %%
# leisure POI
tags = {'leisure': True}
POI_leisure = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_leisure = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_leisure, 'POI_leisure')  
POI_leisure
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid                  geometry  \
# 0      node/28122271    28122271  POINT (6.96900 50.94101)
# 1      node/97753701    97753701  POINT (6.92603 50.96285)
# 2      node/98180411    98180411  POINT (6.92586 50.96427)
# 3     node/137028641   137028641  POINT (6.93278 50.94508)
# 4     node/238028510   238028510  POINT (6.90642 50.97715)
# ..               ...         ...                       ...
# 722  node/8158366351  8158366351  POINT (6.91755 50.94653)
# 723  node/8175168217  8175168217  POINT (6.90674 50.96552)
# 724  node/8187767537  8187767537  POINT (6.93928 50.95491)
# 725  node/8238174660  8238174660  POINT (6.94805 50.97986)
# 726  node/8262138255  8262138255  POINT (6.87584 50.96241)
#
#                                  name amenity  longitude   latitude  \
# 0    Kletteranlage Hohenzollernbrücke     NaN   6.969004  50.941007
# 1                                 NaN     NaN   6.926035  50.962850
# 2                                 NaN     NaN   6.925857  50.964272
# 3                                 NaN     NaN   6.932783  50.945077
# 4                                 NaN     NaN   6.906418  50.977150
# ..                                ...     ...        ...        ...
# 722                               NaN     NaN   6.917550  50.946532
# 723                               NaN     NaN   6.906745  50.965521
# 724       Bogenlust GbR Eventlocation     NaN   6.939280  50.954912
# 725                     Außenterrasse     NaN   6.948053  50.979856
# 726                               NaN     NaN   6.875837  50.962406
#
#      usage_count     POI_type
# 0           4990  POI_leisure
# 1            341  POI_leisure
# 2            163  POI_leisure
# 3           3815  POI_leisure
# 4             11  POI_leisure
# ..           ...          ...
# 722         6105  POI_leisure
# 723         1274  POI_leisure
# 724         2189  POI_leisure
# 725         1357  POI_leisure
# 726          205  POI_leisure
#
# [727 rows x 9 columns]

# %%
# office POI
tags = {'office': True}
POI_office = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_office = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_office, 'POI_office')  
POI_office
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid                        name  \
# 0     node/285569148   285569148                      ampido
# 1     node/297870881   297870881                    Edelgrün
# 2     node/304561103   304561103                 align media
# 3     node/306136792   306136792        GIGATRONIK Köln GmbH
# 4     node/332418979   332418979                  Lieferando
# ..               ...         ...                         ...
# 771  node/8219835707  8219835707            Leidens & Effert
# 772  node/8219835708  8219835708                    XNC GmbH
# 773  node/8242684660  8242684660               ms Immobilien
# 774  node/8242684664  8242684664            AXA - Butz&Hauke
# 775  node/8263989433  8263989433  Ingeneurbüro für Baustatik
#
#                      geometry amenity  longitude   latitude  usage_count  \
# 0    POINT (6.93751 50.94191)     NaN   6.937511  50.941909        13172
# 1    POINT (6.92405 50.94663)    cafe   6.924052  50.946627         8543
# 2    POINT (6.92214 50.95597)     NaN   6.922139  50.955971         4975
# 3    POINT (6.92347 50.97676)     NaN   6.923469  50.976762          396
# 4    POINT (6.91732 50.95049)     NaN   6.917324  50.950488         8935
# ..                        ...     ...        ...        ...          ...
# 771  POINT (7.09764 50.88226)     NaN   7.097643  50.882261            0
# 772  POINT (7.09746 50.88227)     NaN   7.097463  50.882268            0
# 773  POINT (6.88192 50.95550)     NaN   6.881925  50.955504          231
# 774  POINT (6.88138 50.95542)     NaN   6.881377  50.955418          228
# 775  POINT (7.08781 50.85400)     NaN   7.087807  50.854000            0
#
#        POI_type
# 0    POI_office
# 1    POI_office
# 2    POI_office
# 3    POI_office
# 4    POI_office
# ..          ...
# 771  POI_office
# 772  POI_office
# 773  POI_office
# 774  POI_office
# 775  POI_office
#
# [776 rows x 9 columns]

# %%
# sport POI
tags = {'sport': True}
POI_sport = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_sport = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_sport, 'POI_sport')  
POI_sport
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid                              name  \
# 0      node/28122271    28122271  Kletteranlage Hohenzollernbrücke
# 1      node/98180411    98180411                               NaN
# 2     node/246271888   246271888                Olympia Sporthalle
# 3     node/256542878   256542878                               NaN
# 4     node/256742960   256742960                               NaN
# ..               ...         ...                               ...
# 274  node/8137886073  8137886073                               NaN
# 275  node/8185140561  8185140561                  Bogenschule Köln
# 276  node/8187767537  8187767537       Bogenlust GbR Eventlocation
# 277  node/8233414558  8233414558                  Cologne Dartshop
# 278  node/8263783920  8263783920                               NaN
#
#                      geometry amenity  longitude   latitude  usage_count  \
# 0    POINT (6.96900 50.94101)     NaN   6.969004  50.941007         4990
# 1    POINT (6.92586 50.96427)     NaN   6.925857  50.964272          163
# 2    POINT (6.94539 50.96193)     NaN   6.945391  50.961930         2200
# 3    POINT (6.95317 50.96213)     NaN   6.953172  50.962133         6767
# 4    POINT (6.95839 50.95928)     NaN   6.958392  50.959285         2654
# ..                        ...     ...        ...        ...          ...
# 274  POINT (6.87505 50.95417)     NaN   6.875049  50.954168          130
# 275  POINT (6.87429 50.98442)     NaN   6.874288  50.984417            0
# 276  POINT (6.93928 50.95491)     NaN   6.939280  50.954912         2189
# 277  POINT (6.95101 50.97378)     NaN   6.951015  50.973782         2628
# 278  POINT (7.03648 50.94484)     NaN   7.036479  50.944843            0
#
#       POI_type
# 0    POI_sport
# 1    POI_sport
# 2    POI_sport
# 3    POI_sport
# 4    POI_sport
# ..         ...
# 274  POI_sport
# 275  POI_sport
# 276  POI_sport
# 277  POI_sport
# 278  POI_sport
#
# [279 rows x 9 columns]

# %%
# shop POI
tags = {'shop': True}
POI_shop = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_shop = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_shop, 'POI_shop')  
POI_shop
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#             unique_id       osmid                 name  \
# 0       node/28123308    28123308               Eckert
# 1       node/53980042    53980042       JET-Tankstelle
# 2       node/55441040    55441040                Netto
# 3       node/55448627    55448627                  NaN
# 4       node/95083415    95083415                Kamps
# ...               ...         ...                  ...
# 5241  node/8233414558  8233414558     Cologne Dartshop
# 5242  node/8242491620  8242491620           Doña pelos
# 5243  node/8242684654  8242684654  Mercato Olio e Vino
# 5244  node/8253864159  8253864159            Cut World
# 5245  node/8254554284  8254554284                  NaN
#
#                       geometry amenity  longitude   latitude  usage_count  \
# 0     POINT (6.97405 50.94046)     NaN   6.974051  50.940458        11162
# 1     POINT (6.90746 50.94506)    fuel   6.907464  50.945061         4402
# 2     POINT (7.00814 50.94087)     NaN   7.008140  50.940872         2581
# 3     POINT (7.00658 50.94038)     NaN   7.006583  50.940379         2758
# 4     POINT (6.92143 50.95448)     NaN   6.921427  50.954484         4822
# ...                        ...     ...        ...        ...          ...
# 5241  POINT (6.95101 50.97378)     NaN   6.951015  50.973782         2628
# 5242  POINT (6.95789 50.95305)     NaN   6.957891  50.953053         8374
# 5243  POINT (6.88569 50.95537)     NaN   6.885687  50.955375          798
# 5244  POINT (6.92404 50.94690)     NaN   6.924045  50.946896         8129
# 5245  POINT (6.96639 50.97757)     NaN   6.966390  50.977571          927
#
#       POI_type
# 0     POI_shop
# 1     POI_shop
# 2     POI_shop
# 3     POI_shop
# 4     POI_shop
# ...        ...
# 5241  POI_shop
# 5242  POI_shop
# 5243  POI_shop
# 5244  POI_shop
# 5245  POI_shop
#
# [5246 rows x 9 columns]

# %%
# tourism POI
tags = {'tourism': True}
POI_tourism = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_tourism = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_tourism, 'POI_tourism')  
POI_tourism
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid                  geometry  \
# 0      node/28121900    28121900  POINT (6.96862 50.94108)
# 1      node/36752479    36752479  POINT (6.90365 50.93283)
# 2      node/78605265    78605265  POINT (6.95024 50.94056)
# 3     node/215210722   215210722  POINT (6.89459 50.98739)
# 4     node/246466024   246466024  POINT (6.97824 50.96344)
# ..               ...         ...                       ...
# 707  node/8197223417  8197223417  POINT (6.83737 50.93542)
# 708  node/8220385917  8220385917  POINT (6.83292 50.96557)
# 709  node/8231513224  8231513224  POINT (6.96884 50.95722)
# 710  node/8231513225  8231513225  POINT (6.97382 50.95592)
# 711  node/8241385962  8241385962  POINT (6.88897 50.91845)
#
#                                 name amenity  longitude   latitude  \
# 0                                NaN     NaN   6.968617  50.941085
# 1                                NaN     NaN   6.903648  50.932828
# 2           NS-Dokumentationszentrum     NaN   6.950238  50.940565
# 3                           Coloneum     NaN   6.894589  50.987394
# 4                                NaN     NaN   6.978237  50.963439
# ..                               ...     ...        ...        ...
# 707                              NaN     NaN   6.837369  50.935416
# 708                              NaN     NaN   6.832921  50.965575
# 709                              NaN     NaN   6.968843  50.957217
# 710                              NaN     NaN   6.973823  50.955919
# 711  RegioGrün Erlebnisroute Südwest     NaN   6.888969  50.918451
#
#      usage_count     POI_type
# 0           4338  POI_tourism
# 1            801  POI_tourism
# 2          10738  POI_tourism
# 3            532  POI_tourism
# 4           1987  POI_tourism
# ..           ...          ...
# 707          840  POI_tourism
# 708            0  POI_tourism
# 709         1661  POI_tourism
# 710          977  POI_tourism
# 711           44  POI_tourism
#
# [712 rows x 9 columns]

# %%
# transportation POI
tags = {'amenity': ['bicycle_rental','boat_rental', 'boat_sharing', 'bus_station', 'car_rental', 'car_sharing', 'ferry_terminal', 'taxi'],
       'public_transport':['station'],
       'railway':['platform', 'station', 'tram_stop', 'subway_entrance']}
POI_transport = prepare_POI_data(ox.pois.pois_from_place(place=place, tags=tags))
# supplement trip data with POI data selection
data_full, POI_transport = supplement_trip_data_with_POI_data(data_full, trips_start_radians, trips_end_radians, POI_transport, 'POI_transport')  
POI_transport
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\osmnx\pois.py:135: UserWarning: The `pois` module has been deprecated and will be removed in a future release. Use the `geometries` module's `geometries_from_place` function instead.
#   warnings.warn(msg)
#            unique_id       osmid         amenity                     name  \
# 0        node/359829      359829      car_rental   Starcar Autovermietung
# 1        node/359831      359831     car_sharing                      NaN
# 2        node/361716      361716             NaN               Eifelplatz
# 3      node/28122005    28122005             NaN                 Heumarkt
# 4      node/28122013    28122013             NaN         Deutzer Freiheit
# ..               ...         ...             ...                      ...
# 833  node/7022705866  7022705866             NaN               Poststraße
# 834  node/7110567529  7110567529      car_rental       RKG Autovermietung
# 835  node/7334512627  7334512627  bicycle_rental  Charles-de-Gaulle Platz
# 836  node/7673526493  7673526493             NaN              Arnoldshöhe
# 837  node/7673526494  7673526494             NaN              Arnoldshöhe
#
#                      geometry  longitude   latitude  usage_count  \
# 0    POINT (6.96395 50.90492)   6.963953  50.904916         2907
# 1    POINT (6.96358 50.90565)   6.963581  50.905654         3340
# 2    POINT (6.94351 50.92335)   6.943506  50.923349         3398
# 3    POINT (6.95992 50.93570)   6.959924  50.935698        15665
# 4    POINT (6.97137 50.93809)   6.971368  50.938090         6434
# ..                        ...        ...        ...          ...
# 833  POINT (6.94992 50.93205)   6.949917  50.932046         5804
# 834  POINT (6.98132 50.92308)   6.981321  50.923081         2092
# 835  POINT (6.97234 50.94165)   6.972337  50.941653         8513
# 836  POINT (6.96700 50.89463)   6.967003  50.894625          984
# 837  POINT (6.96696 50.89462)   6.966962  50.894623          984
#
#           POI_type
# 0    POI_transport
# 1    POI_transport
# 2    POI_transport
# 3    POI_transport
# 4    POI_transport
# ..             ...
# 833  POI_transport
# 834  POI_transport
# 835  POI_transport
# 836  POI_transport
# 837  POI_transport
#
# [838 rows x 9 columns]

# %%
# show supplemented trip data
pd.options.display.max_columns = None
display(data_full)
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                        id provider  \
# 0        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzE5MTQy   car2go
# 1        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzIxNTM2   car2go
# 2        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMzcyNDA3   car2go
# 3        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkwNTc5   car2go
# 4        ZnJlZWZsb2F0OjpjYXIyZ286OldNRTQ1MzM0MjFLMjkzNjQy   car2go
# ...                                                   ...      ...
# 404858  YmlrZTo6dGllcjo6YTFlMmYzZjEtNjkyZS00NjA4LWE5YT...     tier
# 404859  YmlrZTo6dGllcjo6OGUxYjAwNDUtMDY3NS00Mzc4LTk3Yz...     tier
# 404860  YmlrZTo6dGllcjo6ZGE1NmNkMDgtN2Q5ZS00YzE0LWI2OT...     tier
# 404861  YmlrZTo6dGllcjo6NzRlY2JjZTYtZWQ3Yi00ZGY3LWJmMG...     tier
# 404862  YmlrZTo6dGllcjo6MTdiZDhhNzgtNzFiMy00NzRkLWJhND...     tier
#
#        vehicleType  date_start  time_start    date_end  time_end  year  month  \
# 0              car  2019-11-18        1300  2019-11-18      1310  2019     11
# 1              car  2019-11-18        1300  2019-11-18      1320  2019     11
# 2              car  2019-11-18        1300  2019-11-18      1320  2019     11
# 3              car  2019-11-18        1300  2019-11-18      1325  2019     11
# 4              car  2019-11-18        1300  2019-11-18      1325  2019     11
# ...            ...         ...         ...         ...       ...   ...    ...
# 404858     scooter  2020-02-29        2340  2020-02-29      2350  2020      2
# 404859     scooter  2020-02-29        2340  2020-02-29      2355  2020      2
# 404860     scooter  2020-02-29        2340  2020-02-29      2355  2020      2
# 404861     scooter  2020-02-29        2345  2020-02-29      2350  2020      2
# 404862     scooter  2020-02-29        2345  2020-02-29      2355  2020      2
#
#         weekday  hour  weekend  longitude_start  latitude_start  \
# 0             0    13        0         6.886950       50.947880
# 1             0    13        0         6.954300       50.938210
# 2             0    13        0         6.985220       50.949150
# 3             0    13        0         6.917080       50.946330
# 4             0    13        0         7.018690       50.970100
# ...         ...   ...      ...              ...             ...
# 404858        5    23        1         6.960057       50.940467
# 404859        5    23        1         6.927394       50.915908
# 404860        5    23        1         6.938424       50.928810
# 404861        5    23        1         6.975072       50.964634
# 404862        5    23        1         6.999384       50.937479
#
#         longitude_end  latitude_end  coordinates_start    coordinates_end  \
# 0            6.890660     50.947170   (50.9479, 6.887)  (50.9472, 6.8907)
# 1            6.944940     50.941190  (50.9382, 6.9543)  (50.9412, 6.9449)
# 2            7.014890     50.966520  (50.9492, 6.9852)  (50.9665, 7.0149)
# 3            6.907470     50.951340  (50.9463, 6.9171)  (50.9513, 6.9075)
# 4            6.996920     50.942590  (50.9701, 7.0187)  (50.9426, 6.9969)
# ...               ...           ...                ...                ...
# 404858       6.956911     50.938427  (50.9405, 6.9601)  (50.9384, 6.9569)
# 404859       6.944665     50.904921  (50.9159, 6.9274)  (50.9049, 6.9447)
# 404860       6.928539     50.920578  (50.9288, 6.9384)  (50.9206, 6.9285)
# 404861       6.969438     50.967416  (50.9646, 6.9751)  (50.9674, 6.9694)
# 404862       7.010359     50.940977  (50.9375, 6.9994)   (50.941, 7.0104)
#
#            distance  duration     speed        time_basket  dist_center_start  \
# 0        271.635363     595.0  1.643508    weekday_daytime               5055
# 1        734.795721    1197.0  2.209912    weekday_daytime                486
# 2       2837.091541    1197.0  8.532606    weekday_daytime               2049
# 3        873.828450    1496.0  2.102796    weekday_daytime               2943
# 4       3417.963314    1496.0  8.225045    weekday_daytime               5268
# ...             ...       ...       ...                ...                ...
# 404858   316.302763     600.0  1.897817  weekend_nighttime                179
# 404859  1720.132594     902.0  6.865274  weekend_nighttime               3602
# 404860  1148.006312     902.0  4.581843  weekend_nighttime               2007
# 404861   501.354847     300.0  6.016258  weekend_nighttime               2801
# 404862   861.778117     602.0  5.153490  weekend_nighttime               2906
#
#         dist_center_end POI_aero_start POI_aero_end  \
# 0                  4787              0            0
# 1                   948              0            0
# 2                  4820              0            0
# 3                  3727              0            0
# 4                  2697              0            0
# ...                 ...            ...          ...
# 404858              382              0            0
# 404859             4204              0            0
# 404860             3149              0            0
# 404861             2958              0            0
# 404862             3638              0            0
#
#        POI_art_culture_entertainment_start POI_art_culture_entertainment_end  \
# 0                                        0                                 0
# 1                                        5                                 7
# 2                                        1                                 2
# 3                                        0                                 1
# 4                                        0                                 0
# ...                                    ...                               ...
# 404858                                   8                                 7
# 404859                                   1                                 0
# 404860                                   5                                 1
# 404861                                   0                                 0
# 404862                                   2                                 2
#
#        POI_education_start POI_education_end POI_finance_start  \
# 0                        2                 1                 1
# 1                        2                 1                16
# 2                        0                 1                 0
# 3                        2                 0                 0
# 4                        1                 0                 0
# ...                    ...               ...               ...
# 404858                   2                 1                19
# 404859                   1                 0                 4
# 404860                   6                 3                12
# 404861                   2                 1                 2
# 404862                   1                 6                 7
#
#        POI_finance_end POI_food_drink_start POI_food_drink_end  \
# 0                    0                    7                  5
# 1                    4                   63                 75
# 2                    1                    2                  5
# 3                    0                   18                  4
# 4                    0                    1                  3
# ...                ...                  ...                ...
# 404858              21                   85                109
# 404859               0                   26                  2
# 404860               1                  120                 17
# 404861               0                    9                  0
# 404862               0                   25                 16
#
#        POI_healthcare_start POI_healthcare_end POI_history_start  \
# 0                         0                  0                 0
# 1                         4                  2                35
# 2                         0                  1                 0
# 3                         3                  0                12
# 4                         0                  1                 0
# ...                     ...                ...               ...
# 404858                    7                 10                25
# 404859                    6                  1                15
# 404860                    5                  4               129
# 404861                    6                  0                 0
# 404862                    3                  8                 1
#
#        POI_history_end POI_leisure_start POI_leisure_end POI_office_start  \
# 0                    0                 1               1                4
# 1                   38                 4               3               14
# 2                    0                 0               1                0
# 3                    1                 7               0                7
# 4                    0                 0               4                4
# ...                ...               ...             ...              ...
# 404858              37                 6               9               10
# 404859               0                 2               0                2
# 404860               8                 6               3                3
# 404861               0                 2               2                1
# 404862               0                 3               1                1
#
#        POI_office_end POI_sport_start POI_sport_end POI_shop_start  \
# 0                   2               0             0              9
# 1                  22               2             0            277
# 2                   4               0             1              5
# 3                   3               4             0             38
# 4                   0               0             1              0
# ...               ...             ...           ...            ...
# 404858             17               2             2             97
# 404859              0               1             0             67
# 404860              4               3             1             70
# 404861              0               2             1              9
# 404862             13               1             0             83
#
#        POI_shop_end POI_tourism_start POI_tourism_end POI_transport_start  \
# 0                 2                 1               2                   3
# 1               131                14               8                   7
# 2                 2                 0               0                   1
# 3                 5                 0               1                   1
# 4                 6                 0               1                   1
# ...             ...               ...             ...                 ...
# 404858          278                30              23                  18
# 404859            3                 1               0                   5
# 404860           26                 8               0                  12
# 404861            2                 2               1                   1
# 404862           37                 4               2                   7
#
#        POI_transport_end
# 0                      3
# 1                      4
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 404858                 6
# 404859                 2
# 404860                 2
# 404861                 0
# 404862                 7
#
# [404863 rows x 50 columns]

# %%
data_full.info()
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404863 entries, 0 to 404862
# Data columns (total 50 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   id                                   404863 non-null  object
#  1   provider                             404863 non-null  object
#  2   vehicleType                          404863 non-null  object
#  3   date_start                           404863 non-null  object
#  4   time_start                           404863 non-null  int64
#  5   date_end                             404863 non-null  object
#  6   time_end                             404863 non-null  int64
#  7   year                                 404863 non-null  int64
#  8   month                                404863 non-null  int64
#  9   weekday                              404863 non-null  int64
#  10  hour                                 404863 non-null  int64
#  11  weekend                              404863 non-null  int64
#  12  longitude_start                      404863 non-null  float64
#  13  latitude_start                       404863 non-null  float64
#  14  longitude_end                        404863 non-null  float64
#  15  latitude_end                         404863 non-null  float64
#  16  coordinates_start                    404863 non-null  object
#  17  coordinates_end                      404863 non-null  object
#  18  distance                             404863 non-null  float64
#  19  duration                             404863 non-null  float64
#  20  speed                                404863 non-null  float64
#  21  time_basket                          404863 non-null  object
#  22  dist_center_start                    404863 non-null  int64
#  23  dist_center_end                      404863 non-null  int64
#  24  POI_aero_start                       404863 non-null  object
#  25  POI_aero_end                         404863 non-null  object
#  26  POI_art_culture_entertainment_start  404863 non-null  object
#  27  POI_art_culture_entertainment_end    404863 non-null  object
#  28  POI_education_start                  404863 non-null  object
#  29  POI_education_end                    404863 non-null  object
#  30  POI_finance_start                    404863 non-null  object
#  31  POI_finance_end                      404863 non-null  object
#  32  POI_food_drink_start                 404863 non-null  object
#  33  POI_food_drink_end                   404863 non-null  object
#  34  POI_healthcare_start                 404863 non-null  object
#  35  POI_healthcare_end                   404863 non-null  object
#  36  POI_history_start                    404863 non-null  object
#  37  POI_history_end                      404863 non-null  object
#  38  POI_leisure_start                    404863 non-null  object
#  39  POI_leisure_end                      404863 non-null  object
#  40  POI_office_start                     404863 non-null  object
#  41  POI_office_end                       404863 non-null  object
#  42  POI_sport_start                      404863 non-null  object
#  43  POI_sport_end                        404863 non-null  object
#  44  POI_shop_start                       404863 non-null  object
#  45  POI_shop_end                         404863 non-null  object
#  46  POI_tourism_start                    404863 non-null  object
#  47  POI_tourism_end                      404863 non-null  object
#  48  POI_transport_start                  404863 non-null  object
#  49  POI_transport_end                    404863 non-null  object
# dtypes: float64(7), int64(9), object(34)
# memory usage: 154.4+ MB

# %% [markdown]
# ### Save data sets

# %%
# save data by mode and months
def save_supplemented_data(months, data_supplemented):
    for month in months:
        # extract month, year and mode
        only_month = int(month[4:])
        only_year = int(month[:4])
        mode_name_file = data_supplemented['vehicleType'].iloc[0]
        
        # create dataframe and save it as csv file
        split_cond = [(data_supplemented['month'] == only_month) & (data_supplemented['year'] == only_year)]
        data_supplemented[split_cond[0]].to_csv('Data/Modes/data_supplemented_{}_{}.csv'.format(mode_name_file, month), index = False)

# save data by mode only
def save_supplemented_data_full(data_supplemented):
    # create dataframe and save it as csv file
    data_supplemented[data_supplemented['vehicleType']=='car'].to_csv('Data/Modes/data_supplemented_full_car.csv', index = False)
    data_supplemented[data_supplemented['vehicleType']=='bicycle'].to_csv('Data/Modes/data_supplemented_full_bicycle.csv', index = False)
    data_supplemented[data_supplemented['vehicleType']=='scooter'].to_csv('Data/Modes/data_supplemented_full_scooter.csv', index = False)

# %%
# save POI datasets
# set True if saving is desired
save_data_POI = False
if (save_data_POI):
    POI_data = pd.concat([POI_aero, POI_art_culture_entertainment, POI_education, POI_finance, 
                          POI_food_drink, POI_healthcare, POI_history, POI_leisure, POI_office,
                          POI_sport, POI_shop, POI_tourism, POI_transport], ignore_index=True)
    POI_data.to_csv('Data/POI_data.csv', index = False)

# %%
# save supplemented data sets based on selected months
# split data by month to avoid file size > 100 MB due to GitHub rules
# set True if saving is desired
save_data = False
if (save_data):
    save_supplemented_data(months, data_full[data_full['vehicleType']=='car'])
    save_supplemented_data(months, data_full[data_full['vehicleType']=='bicycle'])
    save_supplemented_data(months, data_full[data_full['vehicleType']=='scooter'])

# %%
# save supplemented data sets in one file per mode
# set True if saving is desired
save_data_full = False
if (save_data_full):
    save_supplemented_data_full(data_full)
# Out:
# C:\Users\User_Vratar\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

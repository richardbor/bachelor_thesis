# %% [markdown]
# Bachelor thesis - Richard Borschke - 7337876 - University of Cologne - A spatio-temporal analysis of usage patterns in free-floating shared mobility
#
#
# # Temporal Patterns
#
# This notebook contains the analysis of temporal patterns. Following content is presented:
# * a
# * b
# * c
# * d

# %% [markdown]
# ### Imports

# %%
import pandas as pd
#pd.options.mode.chained_assignment = None
import glob
import numpy as np
#from numpy import median
#import warnings
#warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set(style="ticks")
sns.set_theme(style="whitegrid")
#from datetime import datetime

# %% [markdown]
# ### Methods

# %%
# load monthly data of mode based on selected months
def load_data(mode, months):
    first_read = True
    for month in months:
        data_month = pd.concat([pd.read_csv(file) for file in glob.glob('Data/Trip_{}/*_trip.csv'.format(month))], ignore_index = True)
        if (first_read):
            data_full = data_month
            first_read = False
        else:
            data_full = pd.concat([data_full, data_month], ignore_index=True)
    return data_full

# load full data of mode
def load_data_mode_full(mode):
    data_mode_full = pd.read_csv('Data/Modes/data_prepared_full_{}.csv'.format(mode))
    return data_mode_full

# %% [markdown]
# ### Execution

# %%
# define months for data loading (YYYYMM)
months = ['201911', '201912', '202001', '202002']

#load_monthly_data = False
#if (load_monthly_data):

# %%
# read in desired data
# set True if full data set load is desired
load_full_data = True
if (load_full_data):
    data_car = load_data_mode_full('car')
    data_bicycle = load_data_mode_full('bicycle')
    data_scooter = load_data_mode_full('scooter')
    data_full = pd.concat([data_car, data_bicycle, data_scooter])

# %%
#indexNames = data_scooter[ data_scooter['provider'] == 'lime' ].index
#data_scooter.drop(indexNames , inplace=True)
# 1974 old
fleet_size_car = len(data_car['id'].unique())
# 2548 old
fleet_size_bicycle = len(data_bicycle['id'].unique())
#7244 old
fleet_size_scooter = len(data_scooter['id'].unique())

fleet_size_scooter
# Out:
# 3220

# %%
select_month = False
if (select_month):
    month = 1
    df_car = data_car[data_car['month']==month]
    df_bicycle = data_bicycle[data_bicycle['month']==month]
    df_scooter = data_scooter[data_scooter['month']==month]

if (select_month == False):
    df_car = data_car
    df_bicycle = data_bicycle
    df_scooter = data_scooter


df_car = df_car.groupby(['date_start','month']).count()
#df_car = df_car.groupby(['date_start', 'provider']).count()
df_car['trip_volume'] = df_car['id']
df_car['utilization'] = df_car['trip_volume']/fleet_size_car
df_car['mode'] = 'car'

df_bicycle = df_bicycle.groupby(['date_start','month']).count()
#df_bicycle = df_bicycle.groupby(['date_start', 'provider']).count()
df_bicycle['trip_volume'] = df_bicycle['id']
df_bicycle['utilization'] = df_bicycle['trip_volume']/fleet_size_bicycle
df_bicycle['mode'] = 'bicycle'

df_scooter = df_scooter.groupby(['date_start','month']).count()
#df_scooter = df_scooter.groupby(['date_start', 'provider']).count()
df_scooter['trip_volume'] = df_scooter['id']
df_scooter['utilization'] = df_scooter['trip_volume']/fleet_size_scooter
df_scooter['mode'] = 'scooter'

df = pd.concat([df_car, df_bicycle, df_scooter])

df = df[['mode', 'trip_volume', 'utilization']]

#row1 = pd.Series([1])
#row2 = pd.Series([1])
#row_df1 = pd.DataFrame([row1], index = ["2020-01-15"])
#row_df2 = pd.DataFrame([row2], index = ["2020-01-16"])
#df = pd.concat([row_df1, rowdf2, df])

df = df.sort_values(['date_start', 'month'])
#df = df.sort_values(['date_start', 'provider'])

g = sns.relplot(x="date_start", y="trip_volume", kind="line", data=df, hue="mode", height=8, aspect=4)
g.fig.autofmt_xdate()


#sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time", row="sex")

# %%
g = sns.relplot(x="date_start", y="utilization", kind="line", data=df, hue="mode", height=8, aspect=4)
g.fig.autofmt_xdate()
#df.head()

# %%
print(df.to_string())
# Out:
#                      mode  trip_volume  utilization
# date_start month
# 2019-11-18 11         car         1388     0.992137
#            11     bicycle           42     0.016706
#            11     scooter          361     0.112112
# 2019-11-19 11         car         2144     1.532523
#            11     bicycle          228     0.090692
#            11     scooter         1426     0.442857
# 2019-11-20 11         car         2127     1.520372
#            11     bicycle          271     0.107796
#            11     scooter         1237     0.384161
# 2019-11-21 11         car         2289     1.636169
#            11     bicycle          221     0.087908
#            11     scooter         1252     0.388820
# 2019-11-22 11         car         2829     2.022159
#            11     bicycle          258     0.102625
#            11     scooter         1305     0.405280
# 2019-11-23 11         car         2548     1.821301
#            11     bicycle          385     0.153142
#            11     scooter         1591     0.494099
# 2019-11-24 11         car         1931     1.380272
#            11     bicycle          301     0.119730
#            11     scooter          766     0.237888
# 2019-11-25 11         car         2108     1.506791
#            11     bicycle          482     0.191726
#            11     scooter         1051     0.326398
# 2019-11-26 11         car         2212     1.581129
#            11     bicycle          533     0.212013
#            11     scooter         1405     0.436335
# 2019-11-27 11         car         2298     1.642602
#            11     bicycle          464     0.184566
#            11     scooter         1487     0.461801
# 2019-11-28 11         car         2535     1.812009
#            11     bicycle          365     0.145187
#            11     scooter         1246     0.386957
# 2019-11-29 11         car         2780     1.987134
#            11     bicycle          566     0.225139
#            11     scooter         2165     0.672360
# 2019-11-30 11         car         2670     1.908506
#            11     bicycle          340     0.135243
#            11     scooter         2170     0.673913
# 2019-12-01 12         car         2109     1.507505
#            12     bicycle          251     0.099841
#            12     scooter         1314     0.408075
# 2019-12-02 12         car         2424     1.732666
#            12     bicycle          364     0.144789
#            12     scooter         1230     0.381988
# 2019-12-03 12         car         2308     1.649750
#            12     bicycle          497     0.197693
#            12     scooter         1626     0.504969
# 2019-12-04 12         car         2312     1.652609
#            12     bicycle          490     0.194909
#            12     scooter         1700     0.527950
# 2019-12-05 12         car         1966     1.405289
#            12     bicycle          466     0.185362
#            12     scooter         1776     0.551553
# 2019-12-06 12     bicycle          331     0.131663
#            12     scooter         1452     0.450932
# 2019-12-07 12     bicycle          435     0.173031
#            12     scooter         2147     0.666770
# 2019-12-08 12     bicycle          266     0.105807
#            12     scooter         1215     0.377329
# 2019-12-09 12     bicycle          375     0.149165
#            12     scooter         1209     0.375466
# 2019-12-10 12         car         1279     0.914224
#            12     bicycle          473     0.188146
#            12     scooter         1541     0.478571
# 2019-12-11 12         car         2722     1.945675
#            12     bicycle          332     0.132060
#            12     scooter         1123     0.348758
# 2019-12-12 12         car         2750     1.965690
#            12     bicycle          452     0.179793
#            12     scooter         1535     0.476708
# 2019-12-13 12         car         3581     2.559685
#            12     bicycle          297     0.118138
#            12     scooter         1253     0.389130
# 2019-12-14 12         car         3258     2.328806
#            12     bicycle          314     0.124901
#            12     scooter         1724     0.535404
# 2019-12-15 12         car         2248     1.606862
#            12     bicycle          258     0.102625
#            12     scooter         1490     0.462733
# 2019-12-16 12         car         2552     1.824160
#            12     bicycle          459     0.182578
#            12     scooter         1352     0.419876
# 2019-12-17 12         car         2556     1.827019
#            12     bicycle          624     0.248210
#            12     scooter         2085     0.647516
# 2019-12-18 12         car         2549     1.822016
#            12     bicycle          571     0.227128
#            12     scooter         2269     0.704658
# 2019-12-19 12         car         2685     1.919228
#            12     bicycle          591     0.235084
#            12     scooter         2771     0.860559
# 2019-12-20 12         car         3010     2.151537
#            12     bicycle          574     0.228321
#            12     scooter         2823     0.876708
# 2019-12-21 12         car         2603     1.860615
#            12     bicycle          400     0.159109
#            12     scooter         3063     0.951242
# 2019-12-22 12         car         2088     1.492495
#            12     bicycle          159     0.063246
#            12     scooter         1567     0.486646
# 2019-12-23 12         car         2400     1.715511
#            12     bicycle          283     0.112570
#            12     scooter         1935     0.600932
# 2019-12-24 12         car         1563     1.117227
#            12     bicycle           93     0.036993
#            12     scooter         1023     0.317702
# 2019-12-25 12         car         1250     0.893495
#            12     bicycle           56     0.022275
#            12     scooter          776     0.240994
# 2019-12-26 12         car         1260     0.900643
#            12     bicycle           99     0.039379
#            12     scooter          974     0.302484
# 2019-12-27 12         car         1978     1.413867
#            12     bicycle          209     0.083134
#            12     scooter         1772     0.550311
# 2019-12-28 12         car         2005     1.433167
#            12     bicycle          204     0.081146
#            12     scooter         1712     0.531677
# 2019-12-29 12         car         1575     1.125804
#            12     bicycle          152     0.060461
#            12     scooter         1590     0.493789
# 2019-12-30 12         car         2059     1.471766
#            12     bicycle          273     0.108592
#            12     scooter         1776     0.551553
# 2019-12-31 12         car         2058     1.471051
#            12     bicycle          191     0.075975
#            12     scooter         2005     0.622671
# 2020-01-01 1          car         1406     1.005004
#            1      bicycle          131     0.052108
#            1      scooter         1251     0.388509
# 2020-01-02 1          car         1854     1.325232
#            1      bicycle          234     0.093079
#            1      scooter         1436     0.445963
# 2020-01-03 1          car         2361     1.687634
#            1      bicycle          278     0.110581
#            1      scooter         1470     0.456522
# 2020-01-04 1          car         2218     1.585418
#            1      bicycle          257     0.102228
#            1      scooter         1823     0.566149
# 2020-01-05 1          car         1718     1.228020
#            1      bicycle          230     0.091488
#            1      scooter         1487     0.461801
# 2020-01-06 1          car         2002     1.431022
#            1      bicycle          434     0.172633
#            1      scooter         1594     0.495031
# 2020-01-07 1          car         2063     1.474625
#            1      bicycle          470     0.186953
#            1      scooter         1701     0.528261
# 2020-01-08 1          car         2159     1.543245
#            1      bicycle          477     0.189737
#            1      scooter         1679     0.521429
# 2020-01-09 1          car         2384     1.704074
#            1      bicycle          426     0.169451
#            1      scooter         1660     0.515528
# 2020-01-10 1          car         2870     2.051465
#            1      bicycle          410     0.163087
#            1      scooter         1779     0.552484
# 2020-01-11 1          car         2508     1.792709
#            1      bicycle          379     0.150756
#            1      scooter         2218     0.688820
# 2020-01-12 1          car         1782     1.273767
#            1      bicycle          274     0.108990
#            1      scooter         1545     0.479814
# 2020-01-13 1          car         2319     1.657613
#            1      bicycle          469     0.186555
#            1      scooter         1768     0.549068
# 2020-01-14 1          car          858     0.613295
#            1      bicycle          101     0.040175
#            1      scooter          465     0.144410
# 2020-01-17 1          car         3011     2.152252
#            1      bicycle          381     0.151551
#            1      scooter         1676     0.520497
# 2020-01-18 1          car         3752     2.681916
#            1      bicycle          402     0.159905
#            1      scooter         2237     0.694720
# 2020-01-19 1          car         2874     2.054325
#            1      bicycle          264     0.105012
#            1      scooter         1510     0.468944
# 2020-01-20 1          car         2693     1.924946
#            1      bicycle          507     0.201671
#            1      scooter         1533     0.476087
# 2020-01-21 1          car         3101     2.216583
#            1      bicycle          490     0.194909
#            1      scooter         1537     0.477329
# 2020-01-22 1          car         3363     2.403860
#            1      bicycle          468     0.186158
#            1      scooter         1479     0.459317
# 2020-01-23 1          car         3119     2.229450
#            1      bicycle          484     0.192522
#            1      scooter         1765     0.548137
# 2020-01-24 1          car         3740     2.673338
#            1      bicycle          417     0.165871
#            1      scooter         1791     0.556211
# 2020-01-25 1          car         3675     2.626876
#            1      bicycle          303     0.120525
#            1      scooter         1928     0.598758
# 2020-01-26 1          car         2591     1.852037
#            1      bicycle          266     0.105807
#            1      scooter         1632     0.506832
# 2020-01-27 1          car         3209     2.293781
#            1      bicycle          395     0.157120
#            1      scooter         1374     0.426708
# 2020-01-28 1          car         2948     2.107219
#            1      bicycle          443     0.176213
#            1      scooter         1653     0.513354
# 2020-01-29 1          car         2990     2.137241
#            1      bicycle          486     0.193317
#            1      scooter         1683     0.522671
# 2020-01-30 1          car         3328     2.378842
#            1      bicycle          475     0.188942
#            1      scooter         1763     0.547516
# 2020-01-31 1          car         3717     2.656898
#            1      bicycle          509     0.202466
#            1      scooter         2305     0.715839
# 2020-02-01 2          car         4063     2.904217
#            2      bicycle          328     0.130469
#            2      scooter         1886     0.585714
# 2020-02-02 2          car         2971     2.123660
#            2      bicycle          259     0.103023
#            2      scooter         1450     0.450311
# 2020-02-03 2          car         3231     2.309507
#            2      bicycle          379     0.150756
#            2      scooter         1419     0.440683
# 2020-02-04 2          car         3232     2.310222
#            2      bicycle          416     0.165473
#            2      scooter         1554     0.482609
# 2020-02-05 2          car         2787     1.992137
#            2      bicycle          477     0.189737
#            2      scooter         1940     0.602484
# 2020-02-06 2          car         2985     2.133667
#            2      bicycle          473     0.188146
#            2      scooter         2015     0.625776
# 2020-02-07 2          car         3638     2.600429
#            2      bicycle          458     0.182180
#            2      scooter         2192     0.680745
# 2020-02-08 2          car         3513     2.511079
#            2      bicycle          371     0.147574
#            2      scooter         2145     0.666149
# 2020-02-09 2          car         2645     1.890636
#            2      bicycle          200     0.079554
#            2      scooter         1359     0.422050
# 2020-02-10 2          car         3053     2.182273
#            2      bicycle          318     0.126492
#            2      scooter         1325     0.411491
# 2020-02-11 2          car         2855     2.040743
#            2      bicycle          391     0.155529
#            2      scooter         1530     0.475155
# 2020-02-12 2          car         2904     2.075768
#            2      bicycle          444     0.176611
#            2      scooter         1603     0.497826
# 2020-02-13 2          car         3239     2.315225
#            2      bicycle          365     0.145187
#            2      scooter         1457     0.452484
# 2020-02-14 2          car         3776     2.699071
#            2      bicycle          444     0.176611
#            2      scooter         2091     0.649379
# 2020-02-15 2          car         3384     2.418871
#            2      bicycle          399     0.158711
#            2      scooter         2412     0.749068
# 2020-02-16 2          car         2703     1.932094
#            2      bicycle          306     0.121718
#            2      scooter         1867     0.579814
# 2020-02-17 2          car         3191     2.280915
#            2      bicycle          507     0.201671
#            2      scooter         1502     0.466460
# 2020-02-18 2          car         3412     2.438885
#            2      bicycle          514     0.204455
#            2      scooter         1650     0.512422
# 2020-02-19 2          car         3836     2.741959
#            2      bicycle          641     0.254972
#            2      scooter         1985     0.616460
# 2020-02-20 2          car         4244     3.033595
#            2      bicycle          603     0.239857
#            2      scooter         1359     0.422050
# 2020-02-21 2          car         4344     3.105075
#            2      bicycle          574     0.228321
#            2      scooter         1147     0.356211
# 2020-02-22 2          car         4146     2.963545
#            2      bicycle          526     0.209228
#            2      scooter         1454     0.451553
# 2020-02-23 2          car         3385     2.419585
#            2      bicycle          228     0.090692
#            2      scooter          930     0.288820
# 2020-02-24 2          car         2661     1.902073
#            2      bicycle          247     0.098250
#            2      scooter          965     0.299689
# 2020-02-25 2          car         3172     2.267334
#            2      bicycle          215     0.085521
#            2      scooter          981     0.304658
# 2020-02-26 2          car         3345     2.390994
#            2      bicycle          157     0.062450
#            2      scooter          894     0.277640
# 2020-02-27 2          car         3452     2.467477
#            2      bicycle          155     0.061655
#            2      scooter          771     0.239441
# 2020-02-28 2          car         3604     2.576126
#            2      bicycle          192     0.076372
#            2      scooter         1429     0.443789
# 2020-02-29 2          car         3245     2.319514
#            2      bicycle          140     0.055688
#            2      scooter         1925     0.597826

# %%
df = df[['trip_volume','mode']]
df.head()
#type(data_car['date_start'])
#row1 = pd.Series(['mode', 'c'])
#row2 = pd.Series(['trip_volume', 0])
#row_df1 = pd.DataFrame([row1], index = ["2020-01-15", 1])
#row_df2 = pd.DataFrame([row2], index = ["2020-01-16", 1])

#df = pd.concat([row_df1, row_df2, df])
df.head()

dfa = pd.concat([data_car, data_bicycle, data_scooter])

dfa['provider'].unique()
#dfa.describe()
# Out:
# array(['car2go', 'driveby', 'fordpass', 'kvb', 'tier', 'circ'],
#       dtype=object)

# %%
#g = sns.relplot(x="date_start", y="trip_volume", kind="line", data=df, hue="mode", row="mode")
#g = sns.relplot(x="date_start", y="trip_volume", kind="line", data=df, hue="mode", col="month", row="mode")
#g.fig.autofmt_xdate()

# %%
observed_days_of_provider = {'car2go': len(data_car[data_car['provider']=='car2go']['date_start'].unique()), 
                             'drivenow': len(data_car[data_car['provider']=='drivenow']['date_start'].unique()),
                             'driveby': len(data_car[data_car['provider']=='driveby']['date_start'].unique()),
                             'kvb': len(data_bicycle[data_bicycle['provider']=='kvb']['date_start'].unique()),
                             'fordpass': len(data_bicycle[data_bicycle['provider']=='fordpass']['date_start'].unique()),
                             'lime': len(data_scooter[data_scooter['provider']=='lime']['date_start'].unique()),
                             'bird': len(data_scooter[data_scooter['provider']=='bird']['date_start'].unique()),
                             'circ': len(data_scooter[data_scooter['provider']=='circ']['date_start'].unique()),
                             'tier': len(data_scooter[data_scooter['provider']=='tier']['date_start'].unique())}
observed_days_of_provider
# Out:
# {'car2go': 98,
#  'drivenow': 0,
#  'driveby': 98,
#  'kvb': 93,
#  'fordpass': 102,
#  'lime': 0,
#  'bird': 0,
#  'circ': 92,
#  'tier': 102}

# %%
def create_time_interval(data_mode):
    data_mode['hour_next'] = data_mode['hour'].astype(int)+1
    data_mode['hour']= data_mode['hour'].astype(str).str.zfill(2) +":00 - "+ (data_mode['hour_next']).astype(str).str.zfill(2) + ":00"
    return data_mode

df_car = data_car.copy()
df_bicycle = data_bicycle.copy()
df_scooter = data_scooter.copy()

#data_car['hour'] = pd.to_datetime(data_full['hour'], format='%Y%m%d')
weekend = 0
df_car = df_car[df_car['weekend']==weekend]
df_bicycle = df_bicycle[df_bicycle['weekend']==weekend]
df_scooter = df_scooter[df_scooter['weekend']==weekend]

total_trip_volume_car = len(df_car)
total_trip_volume_bicycle = len(df_bicycle)
total_trip_volume_scooter = len(df_scooter)

df_car = create_time_interval(df_car)
df_bicycle = create_time_interval(df_bicycle)
df_scooter = create_time_interval(df_scooter)

################################
#df_test = df_bicycle
#df_test = df_test.groupby(['hour', 'weekend']).count()


df_car = df_car.groupby(['hour', 'weekend']).count()
#df_car = df_car.groupby(['date_start', 'provider']).count()
df_car['trip_volume'] = df_car['id']
df_car['utilization'] = df_car['trip_volume']/fleet_size_car
df_car['mode'] = 'car'

df_bicycle = df_bicycle.groupby(['hour', 'weekend']).count()
#df_bicycle = df_bicycle.groupby(['date_start', 'provider']).count()
df_bicycle['trip_volume'] = df_bicycle['id']
df_bicycle['utilization'] = df_bicycle['trip_volume']/fleet_size_bicycle
df_bicycle['mode'] = 'bicycle'

df_scooter = df_scooter.groupby(['hour', 'weekend']).count()
#df_scooter = df_scooter.groupby(['date_start', 'provider']).count()
df_scooter['trip_volume'] = df_scooter['id']
df_scooter['utilization'] = df_scooter['trip_volume']/fleet_size_scooter
df_scooter['mode'] = 'scooter'

df_car['percentage_of_trip_starts_per_category_in_time_interval'] = df_car['trip_volume'] * 100 / total_trip_volume_car
df_bicycle['percentage_of_trip_starts_per_category_in_time_interval'] = df_bicycle['trip_volume'] * 100 / total_trip_volume_bicycle
df_scooter['percentage_of_trip_starts_per_category_in_time_interval'] = df_scooter['trip_volume'] * 100 / total_trip_volume_scooter


df = pd.concat([df_car, df_bicycle, df_scooter])

df = df[['mode', 'trip_volume', 'utilization', 'percentage_of_trip_starts_per_category_in_time_interval']]

#row1 = pd.Series([1])
#row2 = pd.Series([1])
#row_df1 = pd.DataFrame([row1], index = ["2020-01-15"])
#row_df2 = pd.DataFrame([row2], index = ["2020-01-16"])
#df = pd.concat([row_df1, rowdf2, df])

df = df.sort_values(['hour', 'weekend'])
#df = df.sort_values(['date_start', 'provider'])


g = sns.relplot(x="hour", y="percentage_of_trip_starts_per_category_in_time_interval", kind="line", data=df, hue="mode", row='weekend', height=5, aspect=2)
#g.set_rotation(30)
#g.fig.autofmt_xdate()
#g.set(xticks=df.hour[2::8])
g.set_xticklabels(rotation=30)

#sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time", row="sex")

# %%
#len(df_test['hour']=='06:00 - 07:00')
#total_trip_volume_bicycle
#df_bicycle
print(df.to_string())
#df_bicycle.head()
# Out:
#                           mode  trip_volume  utilization  percentage_of_trip_starts_per_category_in_time_interval
# hour          weekend
# 00:00 - 01:00 0            car         1610     1.150822                                                 0.845464
#               0        bicycle          212     0.084328                                                 0.757549
#               0        scooter         2223     0.690373                                                 1.982839
# 01:00 - 02:00 0            car         1161     0.829878                                                 0.609679
#               0        bicycle          103     0.040971                                                 0.368054
#               0        scooter         1467     0.455590                                                 1.308513
# 02:00 - 03:00 0            car         1156     0.826305                                                 0.607054
#               0        bicycle          519     0.206444                                                 1.854565
#               0        scooter          993     0.308385                                                 0.885721
# 03:00 - 04:00 0            car         1739     1.243031                                                 0.913206
#               0        bicycle           66     0.026253                                                 0.235841
#               0        scooter          936     0.290683                                                 0.834879
# 04:00 - 05:00 0            car         3539     2.529664                                                 1.858445
#               0        bicycle          117     0.046539                                                 0.418081
#               0        scooter         1060     0.329193                                                 0.945483
# 05:00 - 06:00 0            car         7127     5.094353                                                 3.742622
#               0        bicycle          469     0.186555                                                 1.675898
#               0        scooter         1695     0.526398                                                 1.511881
# 06:00 - 07:00 0            car        10695     7.644746                                                 5.616296
#               0        bicycle         1445     0.574781                                                 5.163480
#               0        scooter         3864     1.200000                                                 3.446553
# 07:00 - 08:00 0            car        11400     8.148678                                                 5.986515
#               0        bicycle         2434     0.968178                                                 8.697517
#               0        scooter         6026     1.871429                                                 5.374982
# 08:00 - 09:00 0            car         9395     6.715511                                                 4.933623
#               0        bicycle         1596     0.634845                                                 5.703055
#               0        scooter         5874     1.824224                                                 5.239403
# 09:00 - 10:00 0            car         7869     5.624732                                                 4.132270
#               0        bicycle          927     0.368735                                                 3.312489
#               0        scooter         4033     1.252484                                                 3.597296
# 10:00 - 11:00 0            car         8070     5.768406                                                 4.237822
#               0        bicycle         1084     0.431185                                                 3.873504
#               0        scooter         4670     1.450311                                                 4.165477
# 11:00 - 12:00 0            car         8571     6.126519                                                 4.500914
#               0        bicycle         1292     0.513922                                                 4.616759
#               0        scooter         5735     1.781056                                                 5.115420
# 12:00 - 13:00 0            car         9025     6.451036                                                 4.739324
#               0        bicycle         1411     0.561257                                                 5.041987
#               0        scooter         6111     1.897826                                                 5.450799
# 13:00 - 14:00 0            car        10134     7.243746                                                 5.321696
#               0        bicycle         1439     0.572395                                                 5.142040
#               0        scooter         6083     1.889130                                                 5.425824
# 14:00 - 15:00 0            car        10715     7.659042                                                 5.626799
#               0        bicycle         1501     0.597056                                                 5.363588
#               0        scooter         6620     2.055901                                                 5.904809
# 15:00 - 16:00 0            car        12609     9.012866                                                 6.621400
#               0        bicycle         1979     0.787192                                                 7.071646
#               0        scooter         7460     2.316770                                                 6.654060
# 16:00 - 17:00 0            car        14148    10.112938                                                 7.429580
#               0        bicycle         2558     1.017502                                                 9.140611
#               0        scooter         8685     2.697205                                                 7.746718
# 17:00 - 18:00 0            car        14725    10.525375                                                 7.732581
#               0        bicycle         2512     0.999204                                                 8.976237
#               0        scooter         8512     2.643478                                                 7.592408
# 18:00 - 19:00 0            car        12783     9.137241                                                 6.712773
#               0        bicycle         1942     0.772474                                                 6.939432
#               0        scooter         7477     2.322050                                                 6.669224
# 19:00 - 20:00 0            car         9981     7.134382                                                 5.241351
#               0        bicycle         1408     0.560064                                                 5.031267
#               0        scooter         5914     1.836646                                                 5.275082
# 20:00 - 21:00 0            car         8384     5.992852                                                 4.402714
#               0        bicycle         1063     0.422832                                                 3.798463
#               0        scooter         4934     1.532298                                                 4.400956
# 21:00 - 22:00 0            car         7216     5.157970                                                 3.789359
#               0        bicycle          846     0.336516                                                 3.023048
#               0        scooter         4805     1.492236                                                 4.285893
# 22:00 - 23:00 0            car         5249     3.751966                                                 2.756422
#               0        bicycle          642     0.255370                                                 2.294086
#               0        scooter         3780     1.173913                                                 3.371628
# 23:00 - 24:00 0            car         3127     2.235168                                                 1.642090
#               0        bicycle          420     0.167064                                                 1.500804
#               0        scooter         3155     0.979814                                                 2.814150

# %% [markdown]
# ##### Barplot of ratio of trip starts onto weekdays

# %%
# create weekday names for numeric equivalent for dataframe
def create_weekday_name(data_mode):
    data_mode['Weekdays'] = pd.to_datetime(data_mode['date_start'], format='%Y-%m-%d').dt.day_name()
    return data_mode

# prepare data for plotting on weekdays
def prepare_data_for_weekday_barplot(data_mode):
    plot_data = data_mode.copy()
    total_trip_volume = len(plot_data)
    plot_data = create_weekday_name(plot_data)
    # group data by weekday number and weekday names to get trip volume and to calculate the ratio
    plot_data = plot_data.groupby(['weekday', 'Weekdays']).count().reset_index()
    plot_data['trip_volume'] = plot_data['id']
    plot_data['Ratio of trip starts on total number of trips [%]'] = plot_data['trip_volume'] * 100 / total_trip_volume
    plot_data['Mode'] = data_mode['vehicleType'].unique()[0]
    # select important variables
    plot_data = plot_data[['weekday', 'Weekdays', 'Mode', 'Ratio of trip starts on total number of trips [%]']]
    return plot_data

# plot barplot of ratio of trip starts of total number of trips on weekdays
def plot_ratio_trip_starts_on_weekday_barplot(show_all_modes):
    # prepare data for plotting
    plot_data_car = prepare_data_for_weekday_barplot(data_car)
    plot_data_bicycle = prepare_data_for_weekday_barplot(data_bicycle)
    plot_data_scooter = prepare_data_for_weekday_barplot(data_scooter)
    
    # concatenate data modes
    if (show_all_modes):
        plot_data_full = prepare_data_for_weekday_barplot(data_full)
        plot_data_full['Mode'] = 'all modes'
        plot_data = pd.concat([plot_data_car, plot_data_bicycle, plot_data_scooter, plot_data_full])
    else:
        plot_data = pd.concat([plot_data_car, plot_data_bicycle, plot_data_scooter])
      
    # sort by weekday number and weekday names
    plot_data = plot_data.sort_values(['weekday', 'Weekdays'])
    # plot data
    sns.catplot(x="Weekdays", y="Ratio of trip starts on total number of trips [%]", hue="Mode", 
                data=plot_data, kind="bar", height=5, aspect=2)

# %%
# plot a barplot of ratio (of trip starts on total number of trips) onto weekdays without all modes reference
plot_ratio_trip_starts_on_weekday_barplot(False)

# %%
# plot a barplot of ratio (of trip starts on total number of trips) onto weekdays with all modes reference
plot_ratio_trip_starts_on_weekday_barplot(True)

# %% [markdown]
# ##### Histogram of density of duration

# %%
# plot a duration density histogram of selected mode and binwidth in min
def plot_duration_density_histogram(data_mode, binwidth, kde):
    plot_data = data_mode.copy()
    # calculate duration in min
    plot_data['duration'] = plot_data['duration'] / 60
    plot_data = plot_data.rename(columns={"duration": "Duration [min]"})
    sns.displot(plot_data, x="Duration [min]", binwidth=binwidth, height=5, aspect=2, stat='density', kde=kde)

# %%
# plot a duration density histogram of all modes data and binwidth in min and kde if desired
plot_duration_density_histogram(data_full, 5, False)

# %%
# plot a duration density histogram of car data and binwidth in min and kde if desired
plot_duration_density_histogram(data_car, 5, False)

# %%
# plot a duration density histogram of bicycle data and binwidth in min and kde if desired
plot_duration_density_histogram(data_bicycle, 5, False)

# %%
# plot a duration density histogram of scooter data and binwidth in min and kde if desired
plot_duration_density_histogram(data_scooter, 5, False)

# %% [markdown]
# # ENDENDENDEND

# %%
peng = pd.concat([data_car, data_bicycle, data_scooter])
peng = peng[['vehicleType', 'time_start', 'duration', 'weekday']] #'longitude_start','latitude_start','longitude_end','latitude_end']]

#g = sns.pairplot(peng, plot_kws=dict(marker="+", linewidth=0.07), diag_kws=dict(fill=False),)
#g.map_lower(sns.kdeplot, levels=3, color=".2")

# plot_kws={"s": 3},
#x_vars=["time_start", "duration", "weekday",'longitude_end','latitude_end' ], y_vars=["time_start", "duration", "weekday", "latitude_start", "latitude_end"]

# %%
g = sns.relplot(x="hour", y="trip_volume", kind="line", data=df, hue="mode", row='weekday', height=8, aspect=4)
g.fig.autofmt_xdate()

# %%
#df.head()
#len(data_car[data_car['weekend']==1])
#len(data_car)

#.dt.strftime('%H00').head()
d = data_car
d['hour_next'] = d['hour'].astype(int)+1
d['hour']= d['hour'].astype(str).str.zfill(2) +":00 - "+ (d['hour_next']).astype(str).str.zfill(2) + ":00"
d['hour'].head()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? n
# Nothing done.
# 0    13:00 - 1400
# 1    13:00 - 1400
# 2    13:00 - 1400
# 3    13:00 - 1400
# 4    13:00 - 1400
# Name: hour, dtype: object

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap


#define new map
hannover_heat_map = folium.Map(location=(50.937, 6.957),  tiles='Stamen Toner', 
                       zoom_start=12, control_scale=True, max_zoom=20)

# add heat map hannover
hannover_heat_map.add_child(plugins.HeatMap(STR_Nov[['latitude_start', 'longitude_start']], radius=11))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
STR_Nov_scooter = STR_Nov[STR_Nov["vehicleType"]=="kick scooter"]
#len(STR_Nov_scooter)
STR_Nov_scooter.describe()
# Out:
#        date_start   time_start    date_end     time_end  longitude_start  \
# count      2058.0  2058.000000      2058.0  2058.000000      2058.000000
# mean   20200229.0  1363.549563  20200229.0  1386.873178         6.951305
# std           0.0   587.396717         0.0   590.394636         0.028987
# min    20200229.0     0.000000  20200229.0     5.000000         6.868793
# 25%    20200229.0  1035.000000  20200229.0  1045.000000         6.938646
# 50%    20200229.0  1420.000000  20200229.0  1435.000000         6.952490
# 75%    20200229.0  1815.000000  20200229.0  1830.000000         6.963928
# max    20200229.0  2345.000000  20200229.0  2355.000000         7.107601
#
#        latitude_start  longitude_end  latitude_end   fuel_start     fuel_end  \
# count     2058.000000    2058.000000   2058.000000  2058.000000  2058.000000
# mean        50.934892       6.950523     50.935211    69.388727    61.133625
# std          0.016954       0.029131      0.017175    16.782735    18.475019
# min         50.841974       6.869810     50.841974    16.000000    16.000000
# 25%         50.928808       6.937870     50.928858    57.000000    49.000000
# 50%         50.936910       6.951639     50.937136    70.000000    62.000000
# 75%         50.941677       6.962811     50.941945    82.000000    75.000000
# max         50.984521       7.107470     50.984521   100.000000   100.000000
#
#            distance      duration  price_promo_start  price_promo_end  \
# count   2058.000000   2058.000000                0.0              0.0
# mean    1329.345563    847.840622                NaN              NaN
# std     1851.921498    640.678345                NaN              NaN
# min       50.114060    279.000000                NaN              NaN
# 25%      506.509203    599.000000                NaN              NaN
# 50%      905.096494    602.000000                NaN              NaN
# 75%     1587.244302    902.000000                NaN              NaN
# max    16787.563389  11700.000000                NaN              NaN
#
#        missing_file_number  dist_center_start  dist_center_end       c  \
# count               2058.0        2058.000000      2058.000000  2058.0
# mean                   0.0        2229.334477      2246.305656    10.0
# std                    0.0        1880.678210      1897.532230     0.0
# min                    0.0         110.565375       110.565375    10.0
# 25%                    0.0        1022.432524      1029.537231    10.0
# 50%                    0.0        1746.858086      1809.104964    10.0
# 75%                    0.0        3040.111064      3043.331565    10.0
# max                    0.0       15157.902431     15158.676233    10.0
#
#        Weekday         Hour
# count   2058.0  2058.000000
# mean       5.0    13.361516
# std        0.0     5.877829
# min        5.0     0.000000
# 25%        5.0    10.000000
# 50%        5.0    14.000000
# 75%        5.0    18.000000
# max        5.0    23.000000

# %%
#define empty map

STR_map_points = folium.Map(location=(50.937, 6.957),  tiles='Stamen Toner', 
                       zoom_start=11, control_scale=True, max_zoom=20)


# draw positions for selcted cars

positions = list(STR_Nov_scooter["coordinates_start"].unique())
for position in positions:
    folium.CircleMarker(radius=5, location=position, popup='The Waterfront', 
                                 color='crimson', fill_color='crimson').add_to(STR_map_points)
    
STR_map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
STR_map_trajectory = folium.Map(location=(50.937, 6.957),  tiles='Stamen Toner', 
                       zoom_start=12, control_scale=True, max_zoom=20)

# draw trajectory for a selected car

folium.PolyLine(STR_Nov_scooter["coordinates_start"],color="blue", weight=1, opacity=0.8, ).add_to(STR_map_trajectory)
STR_map_trajectory
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
STR_Nov = pd.concat([data_car, data_scooter, data_bicycle])
x = STR_Nov["longitude_start"]
y = STR_Nov["latitude_start"]
xmin = STR_Nov["longitude_start"].min()
xmax = STR_Nov["longitude_start"].max()
ymin = STR_Nov["latitude_start"].min()
ymax = STR_Nov["latitude_start"].max()

fig, axs = plt.subplots(ncols=1, sharey=True, figsize=(13, 11))
fig.subplots_adjust(hspace=0.5, left=0.07, right=0.93)
ax = axs
hb = ax.hexbin(x, y, gridsize=85, cmap='viridis')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("Trip Density Start")
cb = fig.colorbar(hb, ax=ax)
cb.set_label('counts')


plt.show()

# %%
x = STR_Nov["longitude_end"]
y = STR_Nov["latitude_end"]
xmin = STR_Nov["longitude_end"].min()
xmax = STR_Nov["longitude_end"].max()
ymin = STR_Nov["latitude_end"].min()
ymax = STR_Nov["latitude_end"].max()

fig, axs = plt.subplots(ncols=1, sharey=True, figsize=(13, 11))
fig.subplots_adjust(hspace=0.5, left=0.07, right=0.93)
ax = axs
hb = ax.hexbin(x, y, gridsize=85, cmap='viridis')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("Trip Density End")
cb = fig.colorbar(hb, ax=ax)
cb.set_label('counts')


plt.show()

# %%
STR_Nov = data_full
def plot_scatter(df, city_name):
    fig, (ax1) = plt.subplots(figsize=(15,10))

    plt.xlim(0, 300)
    plt.ylim(0, 20000)
    sns.scatterplot(x=df["duration"]/60, y=STR_Nov["dist_center_start"], data=df, ax=ax1)
   
    ax1.set(ylabel='Distance', xlabel='Duration')
    ax1.set_title('T-- ' + city_name)
   
    
plot_scatter(STR_Nov, 'Cologne')
#len(STR_Nov_scooter)

# %%
# Import libraries
from mpl_toolkits import mplot3d
 
 
# Creating dataset
#z = (STR_Nov["distance"]/1000)/(STR_Nov["duration"]/60)
#z = STR_Nov["Hour"]
y = data_car['time_start']
x = data_car["duration"]/60
z = data_car["distance"]/1000

#z = STR_Nov["duration"]
#x = STR_Nov["latitude_start"]
#y = STR_Nov["longitude_start"]
 
# Creating figure
fig = plt.figure(figsize = (15, 15))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x, y, z, color = "green")
plt.title("-")
 
# show plot
plt.show()
